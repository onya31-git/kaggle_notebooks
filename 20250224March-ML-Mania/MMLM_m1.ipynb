# %%
#Optuna CatBoost March Mania 2025 [0.15102]
#https://www.kaggle.com/code/alexkalita/optuna-catboost-march-mania-2025-0-15102/notebook#Modeling

# EDA
import numpy as np 
import pandas as pd  
import seaborn as sns 
import matplotlib.pyplot as plt 

#MLモデル、スケジューラ、チューニング、評価関数
import sklearn
from sklearn.metrics import *
from sklearn.linear_model import *
from sklearn.model_selection import *

#その他
import os
import re
from collections import Counter

# %%
DATA_PATH = "./data/"
for filename in sorted(os.listdir(DATA_PATH)):
    print(filename)
# Out:
# Cities.csv
# Conferences.csv
# MConferenceTourneyGames.csv
# MGameCities.csv
# MMasseyOrdinals.csv
# MNCAATourneyCompactResults.csv
# MNCAATourneyDetailedResults.csv
# MNCAATourneySeedRoundSlots.csv
# MNCAATourneySeeds.csv
# MNCAATourneySlots.csv
# MRegularSeasonCompactResults.csv
# MRegularSeasonDetailedResults.csv
# MSeasons.csv
# MSecondaryTourneyCompactResults.csv
# MSecondaryTourneyTeams.csv
# MTeamCoaches.csv
# MTeamConferences.csv
# MTeamSpellings.csv
# MTeams.csv
# SampleSubmissionStage1.csv
# SampleSubmissionStage2.csv
# SeedBenchmarkStage1.csv
# WConferenceTourneyGames.csv
# WGameCities.csv
# WNCAATourneyCompactResults.csv
# WNCAATourneyDetailedResults.csv
# WNCAATourneySeeds.csv
# WNCAATourneySlots.csv
# WRegularSeasonCompactResults.csv
# WRegularSeasonDetailedResults.csv
# WSeasons.csv
# WSecondaryTourneyCompactResults.csv
# WSecondaryTourneyTeams.csv
# WTeamConferences.csv
# WTeamSpellings.csv
# WTeams.csv

# %%
#　seed
#　conncat()でdfを結合できる
df_seeds = pd.concat([
    pd.read_csv(DATA_PATH + "MNCAATourneySeeds.csv"),
    pd.read_csv(DATA_PATH + "WNCAATourneySeeds.csv"),
],ignore_index=True)

df_seeds.head()
# Out:
#    Season Seed  TeamID
# 0    1985  W01    1207
# 1    1985  W02    1210
# 2    1985  W03    1228
# 3    1985  W04    1260
# 4    1985  W05    1374

# %%
#　season_results
df_season_results = pd.concat([
    pd.read_csv(DATA_PATH + "MRegularSeasonCompactResults.csv"),
    pd.read_csv(DATA_PATH + "WRegularSeasonCompactResults.csv"),
], ignore_index=True)

#　NumOtとWLocを削除
df_season_results.drop(['NumOT', 'WLoc'],axis=1, inplace=True)

#　ScoreGap行を作成
df_season_results['ScoreGap'] = df_season_results['WScore'] - df_season_results['LScore']

df_season_results.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore  ScoreGap
# 0    1985      20     1228      81     1328      64        17
# 1    1985      25     1106      77     1354      70         7
# 2    1985      25     1112      63     1223      56         7
# 3    1985      25     1165      70     1432      54        16
# 4    1985      25     1192      86     1447      74        12

# %%
# num_win行を作成
# df.groupby()で指定したカラムを元に並べ替えた表を所得
num_win = df_season_results.groupby(['Season', 'WTeamID']).count().reset_index()
num_win = num_win[['Season', 'WTeamID', 'DayNum',]].rename(columns={'DayNum': 'NumWins', 'WTeamID': 'TeamID'})                                                            

num_win.head()
# Out:
#    Season  TeamID  NumWins
# 0    1985    1102        5
# 1    1985    1103        9
# 2    1985    1104       21
# 3    1985    1106       10
# 4    1985    1108       19

# %%
num_loss = df_season_results.groupby(['Season','LTeamID']).count().reset_index()
num_loss = num_loss[['Season', 'LTeamID', 'DayNum',]].rename(columns={'DayNum': 'NumLosses', 'LTeamID': 'TeamID'})

num_loss.head()
# Out:
#    Season  TeamID  NumLosses
# 0    1985    1102         19
# 1    1985    1103         14
# 2    1985    1104          9
# 3    1985    1106         14
# 4    1985    1108          6

# %%
#　gap_win行を作成
gap_win = df_season_results.groupby(['Season', 'WTeamID']).mean().reset_index()
gap_win = gap_win[['Season', 'WTeamID', 'ScoreGap',]].rename(columns={'ScoreGap': 'GapWins', 'WTeamID': 'TeamID'})

gap_win.head()
# Out:
#    Season  TeamID    GapWins
# 0    1985    1102  10.000000
# 1    1985    1103   7.555556
# 2    1985    1104  13.190476
# 3    1985    1106   9.500000
# 4    1985    1108  13.842105

# %%
# gap_loss行を作成
gap_loss = df_season_results.groupby(['Season', 'LTeamID']).mean().reset_index()
gap_loss = gap_loss[['Season', 'LTeamID', 'ScoreGap']].rename(columns={"ScoreGap": "GapLosses", "LTeamID": "TeamID"})

gap_loss.head()
# Out:
#    Season  TeamID  GapLosses
# 0    1985    1102   9.947368
# 1    1985    1103   9.857143
# 2    1985    1104   4.777778
# 3    1985    1106  13.285714
# 4    1985    1108  10.666667

# %%
# groupby().count()でSeasonとWTeamIDの重複を解消し、SeasonとTeamIDのみのdfを作成
df_features_season_w = df_season_results.groupby(['Season', 'WTeamID']).count().reset_index()[['Season', 'WTeamID']].rename(columns= {'WTeamID': 'TeamID'})
df_features_season_l = df_season_results.groupby(['Season', 'LTeamID']).count().reset_index()[['Season', 'LTeamID']].rename(columns={"LTeamID": "TeamID"})

df_features_season_l.head()
# Out:
#    Season  TeamID
# 0    1985    1102
# 1    1985    1103
# 2    1985    1104
# 3    1985    1106
# 4    1985    1108

# %%
df_features_season = pd.concat([df_features_season_w, df_features_season_l], axis=0).drop_duplicates().sort_values(['Season', 'TeamID']).reset_index(drop=True)

# %%
#マージ
df_features_season = df_features_season.merge(num_win, on=['Season', 'TeamID'], how='left')
df_features_season = df_features_season.merge(num_loss, on=['Season', 'TeamID'], how='left')
df_features_season = df_features_season.merge(gap_win, on=['Season', 'TeamID'], how='left')
df_features_season = df_features_season.merge(gap_loss, on=['Season', 'TeamID'], how='left')

#dfの欠損値を埋める
df_features_season.fillna(0, inplace=True)  

df_features_season.head()
# Out:
#    Season  TeamID  NumWins  NumLosses    GapWins  GapLosses
# 0    1985    1102      5.0       19.0  10.000000   9.947368
# 1    1985    1103      9.0       14.0   7.555556   9.857143
# 2    1985    1104     21.0        9.0  13.190476   4.777778
# 3    1985    1106     10.0       14.0   9.500000  13.285714
# 4    1985    1108     19.0        6.0  13.842105  10.666667

# %%
df_features_season['WinRatio'] = df_features_season['NumWins'] / (df_features_season['NumWins'] + df_features_season['NumLosses'])
df_features_season['GapAvg'] = ((df_features_season['NumWins'] * df_features_season['GapWins'] - df_features_season['NumLosses'] * df_features_season['GapLosses']) / (df_features_season['NumWins'] + df_features_season['NumLosses']))

df_features_season.drop(['NumWins', 'NumLosses', 'GapWins', 'GapLosses'], axis=1, inplace=True)

# %%
df_tourney_results = pd.concat([
    pd.read_csv(DATA_PATH + "WNCAATourneyCompactResults.csv"),
    pd.read_csv(DATA_PATH + "MNCAATourneyCompactResults.csv"),
], ignore_index=True)
df_tourney_results.drop(['NumOT', 'WLoc'], axis=1, inplace=True)

# %%
#特徴量エンジニアリング
df = df_tourney_results.copy()
df = df[df['Season'] >= 2016].reset_index(drop=True)

df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore
# 0    2016     137     3107      61     3196      59
# 1    2016     137     3113      74     3308      52
# 2    2016     137     3120      68     3385      57
# 3    2016     137     3124      89     3225      59
# 4    2016     137     3177      97     3241      67

# %%
df = pd.merge(df, df_seeds, how='left', left_on=['Season', 'WTeamID'], right_on=['Season', 'TeamID']).drop('TeamID', axis=1).rename(columns={'Seed':'SeedW'})
df = pd.merge(df, df_seeds, how='left', left_on=['Season', 'LTeamID'], right_on=['Season', 'TeamID']).drop('TeamID', axis=1).rename(columns={'Seed':'SeedL'})

df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore SeedW SeedL
# 0    2016     137     3107      61     3196      59   Z12   Z05
# 1    2016     137     3113      74     3308      52   Z02   Z15
# 2    2016     137     3120      68     3385      57   X09   X08
# 3    2016     137     3124      89     3225      59   X01   X16
# 4    2016     137     3177      97     3241      67   X06   X11

# %%
def treat_seed(seed):
    return int(re.sub("[^0-9]", "", seed))

df['SeedW'] = df['SeedW'].apply(treat_seed)
df['SeedL'] = df['SeedL'].apply(treat_seed)

df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore  SeedW  SeedL
# 0    2016     137     3107      61     3196      59     12      5
# 1    2016     137     3113      74     3308      52      2     15
# 2    2016     137     3120      68     3385      57      9      8
# 3    2016     137     3124      89     3225      59      1     16
# 4    2016     137     3177      97     3241      67      6     11

# %%
df = pd.merge(
    df,
    df_features_season,
    how='left',
    left_on=['Season', 'WTeamID'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'NumWins': 'NumWinsW',
    'NumLosses': 'NumLossesW',
    'GapWins': 'GapWinsW',
    'GapLosses': 'GapLossesW',
    'WinRatio': 'WinRatioW',
    'GapAvg': 'GapAvgW',
}).drop(columns='TeamID', axis=1)

# %%
df = pd.merge(
    df,
    df_features_season,
    how='left',
    left_on=['Season', 'LTeamID'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'NumWins': 'NumWinsL',
    'NumLosses': 'NumLossesL',
    'GapWins': 'GapWinsL',
    'GapLosses': 'GapLossesL',
    'WinRatio': 'WinRatioL',
    'GapAvg': 'GapAvgL',
}).drop(columns='TeamID', axis=1)

# %%
df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore  SeedW  SeedL  WinRatioW  \
# 0    2016     137     3107      61     3196      59     12      5   0.870968
# 1    2016     137     3113      74     3308      52      2     15   0.806452
# 2    2016     137     3120      68     3385      57      9      8   0.612903
# 3    2016     137     3124      89     3225      59      1     16   0.970588
# 4    2016     137     3177      97     3241      67      6     11   0.757576
#
#      GapAvgW  WinRatioL    GapAvgL
# 0  18.677419   0.733333   8.700000
# 1   9.258065   0.857143   8.964286
# 2   3.032258   0.718750   6.812500
# 3  24.617647   0.709677  10.612903
# 4  16.272727   0.843750  15.406250

# %%
def add_loosing_matches(df):
    win_rename = {
        'WTeamID': 'TeamIdA',
        'WScore': 'ScoreA',
        'LTeamID': 'TeamIdB',
        'LScore': 'ScoreB'
    }
    win_rename.update({c : c[:-1] + "A" for c in df.columns if c.endswith('W')})
    win_rename.update({c : c[:-1] + "B" for c in df.columns if c.endswith('L')})

    lose_rename = {
        "WTeamID": "TeamIdB", 
        "WScore" : "ScoreB", 
        "LTeamID" : "TeamIdA",
        "LScore": "ScoreA",
    }
    lose_rename.update({c : c[:-1] + "B" for c in df.columns if c.endswith('W')})
    lose_rename.update({c : c[:-1] + "A" for c in df.columns if c.endswith('L')})

    win_df = df.copy()
    lose_df = df.copy()
    
    win_df = win_df.rename(columns=win_rename)
    lose_df = lose_df.rename(columns=lose_rename)
    
    return pd.concat([win_df, lose_df], axis=0, sort=False)

df = add_loosing_matches(df)
df.head()
# Out:
#    Season  DayNum  TeamIdA  ScoreA  TeamIdB  ScoreB  SeedA  SeedB  WinRatioA  \
# 0    2016     137     3107      61     3196      59     12      5   0.870968
# 1    2016     137     3113      74     3308      52      2     15   0.806452
# 2    2016     137     3120      68     3385      57      9      8   0.612903
# 3    2016     137     3124      89     3225      59      1     16   0.970588
# 4    2016     137     3177      97     3241      67      6     11   0.757576
#
#      GapAvgA  WinRatioB    GapAvgB
# 0  18.677419   0.733333   8.700000
# 1   9.258065   0.857143   8.964286
# 2   3.032258   0.718750   6.812500
# 3  24.617647   0.709677  10.612903
# 4  16.272727   0.843750  15.406250

# %%
# 相違点
# 各機能についてチーム間の差を計算する
# これは、チームAがチームBよりどれだけ優れているか(または劣っているのか)を更に評価するのに役立つ

cols_to_diff = [
    'Seed', 'WinRatio', 'GapAvg'
]

for col in cols_to_diff:
    df[col + 'Diff'] = df[col + 'A'] - df[col + 'B']

# %%
# テストデータの準備
df_test = pd.read_csv(DATA_PATH + "SampleSubmissionStage1.csv")

df_test['Season'] = df_test['ID'].apply(lambda x: int(x.split('_')[0]))
df_test['TeamIdA'] = df_test['ID'].apply(lambda x: int(x.split('_')[1]))
df_test['TeamIdB'] = df_test['ID'].apply(lambda x: int(x.split('_')[2]))

df_test.head()
# Out:
#                ID  Pred  Season  TeamIdA  TeamIdB
# 0  2021_1101_1102   0.5    2021     1101     1102
# 1  2021_1101_1103   0.5    2021     1101     1103
# 2  2021_1101_1104   0.5    2021     1101     1104
# 3  2021_1101_1105   0.5    2021     1101     1105
# 4  2021_1101_1106   0.5    2021     1101     1106

# %%
# テストデータの準備(stage2)
df_test_s2 = pd.read_csv(DATA_PATH + "SampleSubmissionStage2.csv")

df_test_s2['Season'] = df_test_s2['ID'].apply(lambda x: int(x.split('_')[0]))
df_test_s2['TeamIdA'] = df_test_s2['ID'].apply(lambda x: int(x.split('_')[1]))
df_test_s2['TeamIdB'] = df_test_s2['ID'].apply(lambda x: int(x.split('_')[2]))

df_test_s2.head()
# Out:
#                ID  Pred  Season  TeamIdA  TeamIdB
# 0  2025_1101_1102   0.5    2025     1101     1102
# 1  2025_1101_1103   0.5    2025     1101     1103
# 2  2025_1101_1104   0.5    2025     1101     1104
# 3  2025_1101_1105   0.5    2025     1101     1105
# 4  2025_1101_1106   0.5    2025     1101     1106

# %%
df_test = pd.merge(
    df_test,
    df_seeds,
    how='left',
    left_on=['Season', 'TeamIdA'],
    right_on=['Season', 'TeamID']
).drop('TeamID', axis=1).rename(columns={'Seed': 'SeedA'}).fillna('W01')

df_test = pd.merge(
    df_test, 
    df_seeds, 
    how='left', 
    left_on=['Season', 'TeamIdB'], 
    right_on=['Season', 'TeamID']
).drop('TeamID', axis=1).rename(columns={'Seed': 'SeedB'}).fillna('W01')

df_test['SeedA'] = df_test['SeedA'].apply(treat_seed)
df_test['SeedB'] = df_test['SeedB'].apply(treat_seed)

# %%
df_test_s2 = pd.merge(
    df_test_s2,
    df_seeds,
    how='left',
    left_on=['Season', 'TeamIdA'],
    right_on=['Season', 'TeamID']
).drop('TeamID', axis=1).rename(columns={'Seed': 'SeedA'}).fillna('W01')

df_test_s2 = pd.merge(
    df_test_s2, 
    df_seeds, 
    how='left', 
    left_on=['Season', 'TeamIdB'], 
    right_on=['Season', 'TeamID']
).drop('TeamID', axis=1).rename(columns={'Seed': 'SeedB'}).fillna('W01')

df_test_s2['SeedA'] = df_test_s2['SeedA'].apply(treat_seed)
df_test_s2['SeedB'] = df_test_s2['SeedB'].apply(treat_seed)

# %%
df_test = pd.merge(
    df_test,
    df_features_season,
    how='left',
    left_on=['Season', 'TeamIdA'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'NumWins': 'NumWinsA',
    'NumLosses': 'NumLossesA',
    'GapWins': 'GapWinsA',
    'GapLosses': 'GapLossesA',
    'WinRatio': 'WinRatioA',
    'GapAvg': 'GapAvgA',
}).drop(columns='TeamID', axis=1)

df_test = pd.merge(
    df_test,
    df_features_season,
    how='left',
    left_on=['Season', 'TeamIdB'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'NumWins': 'NumWinsB',
    'NumLosses': 'NumLossesB',
    'GapWins': 'GapWinsB',
    'GapLosses': 'GapLossesB',
    'WinRatio': 'WinRatioB',
    'GapAvg': 'GapAvgB',
}).drop(columns='TeamID', axis=1)

# %%
df_test_s2 = pd.merge(
    df_test_s2,
    df_features_season,
    how='left',
    left_on=['Season', 'TeamIdA'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'NumWins': 'NumWinsA',
    'NumLosses': 'NumLossesA',
    'GapWins': 'GapWinsA',
    'GapLosses': 'GapLossesA',
    'WinRatio': 'WinRatioA',
    'GapAvg': 'GapAvgA',
}).drop(columns='TeamID', axis=1)

df_test_s2 = pd.merge(
    df_test_s2,
    df_features_season,
    how='left',
    left_on=['Season', 'TeamIdB'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'NumWins': 'NumWinsB',
    'NumLosses': 'NumLossesB',
    'GapWins': 'GapWinsB',
    'GapLosses': 'GapLossesB',
    'WinRatio': 'WinRatioB',
    'GapAvg': 'GapAvgB',
}).drop(columns='TeamID', axis=1)

# %%
for col in cols_to_diff:
    df_test[col + 'Diff'] = df_test[col + 'A'] - df_test[col + 'B']

# %%
for col in cols_to_diff:
    df_test_s2[col + 'Diff'] = df_test_s2[col + 'A'] - df_test_s2[col + 'B']

# %%
df['ScoreDiff'] = df['ScoreA'] - df['ScoreB']
df['WinA'] = (df['ScoreDiff'] > 0).astype(int)

# %%
#モデリング
features = ['SeedA', 'SeedB', 'WinRatioA', 'GapAvgA', 'WinRatioB', 'GapAvgB', 'SeedDiff', 'WinRatioDiff', 'GapAvgDiff']

def rescale(features, df_train, df_val, df_test=None):
    min_ = df_train[features].min()
    max_ = df_train[features].max()
    
    df_train[features] = (df_train[features] - min_) / (max_ - min_ ) 
    df_val[features] = (df_val[features] - min_) / (max_ - min_ ) 
    
    if df_test is not None:
        df_test[features] = (df_test[features] - min_) / (max_ - min_ ) 
        
    return df_train, df_val, df_test

# %%
# cross validation
# 過去３シーズンのnシーズンを検証します。

from catboost import CatBoostRegressor
import optuna
from sklearn.metrics import brier_score_loss

def kfold(df, model, df_test_=None, plot=False, verbose=0, mode="reg"):
    seasons = df['Season'].unique()
    cvs = []
    pred_tests = []
    target = "ScoreDiff" if mode == "reg" else "WinA"
    
    for season in seasons[1:]:
        if verbose:
            print(f'\nValidating on season {season}')
        
        df_train = df[df['Season'] < season].reset_index(drop=True).copy()
        df_val = df[df['Season'] == season].reset_index(drop=True).copy()
        df_test = df_test_.copy()
        df_train.fillna(0, inplace=True)  #### add this code for fixing a bug
        df_val.fillna(0, inplace=True)    #### add this code for fixing a bug
        df_test.fillna(0, inplace=True)   #### add this code for fixing a bug
        df_train, df_val, df_test = rescale(features, df_train, df_val, df_test)
        
        if mode == "reg":
            model = ElasticNet(alpha=1, l1_ratio=0.5)
        else:
            model = model

        model.fit(df_train[features], df_train[target])
        
        if mode == "reg":
            pred = model.predict(df_val[features])
        else:
            pred = model.predict(df_val[features])
        
        if df_test is not None:
            if mode == "reg":
                pred_test = model.predict(df_test[features])
                
#                 print( pred_test.max() - pred_test.min())
                pred_test = (pred_test - pred_test.min()) / (pred_test.max() - pred_test.min())
            else:
                pred_test = model.predict(df_test[features])
                
            pred_tests.append(pred_test)
            
        if plot:
            plt.figure(figsize=(15, 6))
            plt.subplot(1, 2, 1)
            plt.scatter(pred, df_val['ScoreDiff'].values, s=5)
            plt.title('Prediction vs Score Diff')
            plt.grid(True)
            plt.subplot(1, 2, 2)
            sns.histplot(pred, bins=20)
            plt.title('Predictions probability repartition')
            plt.show()
        
        pred = (pred - pred.min()) / (pred.max() - pred.min())
        pred = np.clip(pred, 0, 1)

        score = ((df_val['WinA'].values - pred) ** 2).mean()
        cvs.append(score)

        if verbose:
            print(f'\t -> Scored {score:.3f}')
        
    print(f'\n Local CV is {np.mean(cvs):.3f}')
    
    return pred, df_val['WinA'].values

def objective(trial):
    cat_params = dict(
        iterations=trial.suggest_int("iterations", 100, 1000),
        learning_rate=trial.suggest_float("learning_rate", 1e-4, 1e-1, log=True),
        depth=trial.suggest_int("depth", 3, 12),
        l2_leaf_reg=trial.suggest_float("l2_leaf_reg", 1e-8, 100.0, log=True),
        bagging_temperature=trial.suggest_float('bagging_temperature', 0, 2.5),
        random_strength=trial.suggest_float("random_strength", 1e-8, 10.0, log=True),
        task_type='CPU',
        early_stopping_rounds=200,
        verbose=False
    )
    
    model = CatBoostRegressor(**cat_params)

    
    y_pred , y_val = kfold(df, model, df_test, plot=False, verbose=1, mode="cls")
    score = brier_score_loss(y_val, y_pred)
    
    return score



study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=5)
# Out:
# [I 2025-03-06 19:46:00,929] A new study created in memory with name: no-name-3b0c0b5b-1576-42f8-ab46-73126a8addbf
# Validating on season 2017
# 	 -> Scored 0.194
#
# Validating on season 2018
# 	 -> Scored 0.225
#
# Validating on season 2019
# 	 -> Scored 0.156
#
# Validating on season 2021
# 	 -> Scored 0.195
#
# Validating on season 2022
# 	 -> Scored 0.192
#
# Validating on season 2023
# 	 -> Scored 0.192
#
# Validating on season 2024
# [I 2025-03-06 19:47:28,837] Trial 0 finished with value: 0.15792680205414228 and parameters: {'iterations': 615, 'learning_rate': 0.0006225217882044358, 'depth': 11, 'l2_leaf_reg': 0.0017041342410494256, 'bagging_temperature': 0.6692158753461799, 'random_strength': 1.0116188915021114e-07}. Best is trial 0 with value: 0.15792680205414228.
# 	 -> Scored 0.158
#
#  Local CV is 0.187
#
# Validating on season 2017
# 	 -> Scored 0.198
#
# Validating on season 2018
# 	 -> Scored 0.224
#
# Validating on season 2019
# 	 -> Scored 0.165
#
# Validating on season 2021
# 	 -> Scored 0.190
#
# Validating on season 2022
# 	 -> Scored 0.198
#
# Validating on season 2023
# 	 -> Scored 0.199
#
# Validating on season 2024
# [I 2025-03-06 19:47:41,424] Trial 1 finished with value: 0.15822119467829693 and parameters: {'iterations': 728, 'learning_rate': 0.011504783036411457, 'depth': 8, 'l2_leaf_reg': 0.0001747519372342445, 'bagging_temperature': 2.0079480117647472, 'random_strength': 0.02455817867233486}. Best is trial 0 with value: 0.15792680205414228.
# 	 -> Scored 0.158
#
#  Local CV is 0.190
#
# Validating on season 2017
# 	 -> Scored 0.182
#
# Validating on season 2018
# 	 -> Scored 0.206
#
# Validating on season 2019
# 	 -> Scored 0.152
#
# Validating on season 2021
# 	 -> Scored 0.198
#
# Validating on season 2022
# 	 -> Scored 0.196
#
# Validating on season 2023
# 	 -> Scored 0.187
#
# Validating on season 2024
# [I 2025-03-06 19:47:48,780] Trial 2 finished with value: 0.15962256312405257 and parameters: {'iterations': 953, 'learning_rate': 0.0001046830467603985, 'depth': 6, 'l2_leaf_reg': 3.010696916010318e-07, 'bagging_temperature': 0.16371444383682682, 'random_strength': 0.0015491854121210192}. Best is trial 0 with value: 0.15792680205414228.
# 	 -> Scored 0.160
#
#  Local CV is 0.183
#
# Validating on season 2017
# 	 -> Scored 0.184
#
# Validating on season 2018
# 	 -> Scored 0.213
#
# Validating on season 2019
# 	 -> Scored 0.157
#
# Validating on season 2021
# 	 -> Scored 0.187
#
# Validating on season 2022
# 	 -> Scored 0.193
#
# Validating on season 2023
# 	 -> Scored 0.192
#
# Validating on season 2024
# [I 2025-03-06 19:47:59,591] Trial 3 finished with value: 0.15622429996411574 and parameters: {'iterations': 611, 'learning_rate': 0.012821729086031637, 'depth': 8, 'l2_leaf_reg': 26.53469531642888, 'bagging_temperature': 2.3876670124946524, 'random_strength': 1.9609089528199352e-07}. Best is trial 3 with value: 0.15622429996411574.
# 	 -> Scored 0.156
#
#  Local CV is 0.183
#
# Validating on season 2017
# 	 -> Scored 0.178
#
# Validating on season 2018
# 	 -> Scored 0.215
#
# Validating on season 2019
# 	 -> Scored 0.164
#
# Validating on season 2021
# 	 -> Scored 0.187
#
# Validating on season 2022
# 	 -> Scored 0.192
#
# Validating on season 2023
# 	 -> Scored 0.194
#
# Validating on season 2024
# [I 2025-03-06 19:48:39,388] Trial 4 finished with value: 0.15542456744323466 and parameters: {'iterations': 525, 'learning_rate': 0.00984502939636966, 'depth': 10, 'l2_leaf_reg': 0.0798854706139778, 'bagging_temperature': 2.475599644729008, 'random_strength': 1.2022912205499667}. Best is trial 4 with value: 0.15542456744323466.
# 	 -> Scored 0.155
#
#  Local CV is 0.184

# %%
best_params = study.best_params

final_model = CatBoostRegressor(**best_params)
final_model

def kfold(df, model, df_test_=None, plot=False, verbose=0, mode="reg"):
    seasons = df['Season'].unique()
    cvs = []
    pred_tests = []
    target = "ScoreDiff" if mode == "reg" else "WinA"
    
    for season in seasons[1:]:
        if verbose:
            print(f'\nValidating on season {season}')
        
        df_train = df[df['Season'] < season].reset_index(drop=True).copy()
        df_val = df[df['Season'] == season].reset_index(drop=True).copy()
        df_test = df_test_.copy()
        df_train.fillna(0, inplace=True)  #### add this code for fixing a bug
        df_val.fillna(0, inplace=True)    #### add this code for fixing a bug
        df_test.fillna(0, inplace=True)   #### add this code for fixing a bug
        df_train, df_val, df_test = rescale(features, df_train, df_val, df_test)
        
        if mode == "reg":
#             model = LinearRegression()
            model = ElasticNet(alpha=1, l1_ratio=0.5)
        else:
            model = model

        model.fit(df_train[features], df_train[target])
        
        if mode == "reg":
            pred = model.predict(df_val[features])
        else:
            pred = model.predict(df_val[features])
        
        if df_test is not None:
            if mode == "reg":
                pred_test = model.predict(df_test[features])
                
#                 print( pred_test.max() - pred_test.min())
                pred_test = (pred_test - pred_test.min()) / (pred_test.max() - pred_test.min())
            else:
                pred_test = model.predict(df_test[features])
                
            pred_tests.append(pred_test)
            
        if plot:
            plt.figure(figsize=(15, 6))
            plt.subplot(1, 2, 1)
            plt.scatter(pred, df_val['ScoreDiff'].values, s=5)
            plt.title('Prediction vs Score Diff')
            plt.grid(True)
            plt.subplot(1, 2, 2)
            sns.histplot(pred, bins=20)
            plt.title('Predictions probability repartition')
            plt.show()
        
        pred = (pred - pred.min()) / (pred.max() - pred.min())
        pred = np.clip(pred, 0, 1)

        score = ((df_val['WinA'].values - pred) ** 2).mean()
        cvs.append(score)

        if verbose:
            print(f'\t -> Scored {score:.3f}')
        
    print(f'\n Local CV is {np.mean(cvs):.3f}')
    
    return pred_tests

pred_tests = kfold(df, final_model, df_test, plot=False, verbose=1, mode="cls")
pred_tests_s2 = kfold(df, final_model, df_test_s2, plot=False, verbose=1, mode="cls")
# Out:
# Validating on season 2017
# 0:	learn: 0.4975666	total: 9.29ms	remaining: 4.87s
# 1:	learn: 0.4954350	total: 17.8ms	remaining: 4.65s
# 2:	learn: 0.4937790	total: 22.6ms	remaining: 3.93s
# 3:	learn: 0.4915688	total: 31.1ms	remaining: 4.04s
# 4:	learn: 0.4903047	total: 32ms	remaining: 3.32s
# 5:	learn: 0.4878538	total: 40.7ms	remaining: 3.52s
# 6:	learn: 0.4858390	total: 49.5ms	remaining: 3.66s
# 7:	learn: 0.4842507	total: 58.2ms	remaining: 3.76s
# 8:	learn: 0.4819339	total: 66.7ms	remaining: 3.82s
# 9:	learn: 0.4798157	total: 75.2ms	remaining: 3.87s
# 10:	learn: 0.4777290	total: 84.5ms	remaining: 3.95s
# 11:	learn: 0.4760248	total: 93.4ms	remaining: 3.99s
# 12:	learn: 0.4741677	total: 102ms	remaining: 4.03s
# 13:	learn: 0.4721719	total: 112ms	remaining: 4.07s
# 14:	learn: 0.4702042	total: 121ms	remaining: 4.1s
# 15:	learn: 0.4683985	total: 131ms	remaining: 4.16s
# 16:	learn: 0.4665927	total: 140ms	remaining: 4.2s
# 17:	learn: 0.4649827	total: 149ms	remaining: 4.18s
# 18:	learn: 0.4631340	total: 158ms	remaining: 4.2s
# 19:	learn: 0.4615267	total: 166ms	remaining: 4.19s
# 20:	learn: 0.4597014	total: 175ms	remaining: 4.2s
# 21:	learn: 0.4579182	total: 183ms	remaining: 4.19s
# 22:	learn: 0.4560575	total: 192ms	remaining: 4.2s
# 23:	learn: 0.4543934	total: 201ms	remaining: 4.2s
# 24:	learn: 0.4531306	total: 203ms	remaining: 4.05s
# 25:	learn: 0.4512017	total: 211ms	remaining: 4.05s
# 26:	learn: 0.4495350	total: 220ms	remaining: 4.06s
# 27:	learn: 0.4473905	total: 229ms	remaining: 4.06s
# 28:	learn: 0.4455745	total: 237ms	remaining: 4.06s
# 29:	learn: 0.4436615	total: 246ms	remaining: 4.05s
# 30:	learn: 0.4421460	total: 254ms	remaining: 4.05s
# 31:	learn: 0.4406481	total: 263ms	remaining: 4.04s
# 32:	learn: 0.4391338	total: 271ms	remaining: 4.04s
# 33:	learn: 0.4373917	total: 280ms	remaining: 4.05s
# 34:	learn: 0.4353235	total: 289ms	remaining: 4.05s
# 35:	learn: 0.4337789	total: 298ms	remaining: 4.05s
# 36:	learn: 0.4325159	total: 306ms	remaining: 4.04s
# 37:	learn: 0.4305910	total: 315ms	remaining: 4.03s
# 38:	learn: 0.4295418	total: 323ms	remaining: 4.02s
# 39:	learn: 0.4278703	total: 332ms	remaining: 4.02s
# 40:	learn: 0.4262647	total: 341ms	remaining: 4.02s
# 41:	learn: 0.4246161	total: 349ms	remaining: 4.01s
# 42:	learn: 0.4229008	total: 360ms	remaining: 4.04s
# 43:	learn: 0.4213472	total: 372ms	remaining: 4.07s
# 44:	learn: 0.4196243	total: 384ms	remaining: 4.09s
# 45:	learn: 0.4180453	total: 395ms	remaining: 4.11s
# 46:	learn: 0.4162663	total: 404ms	remaining: 4.11s
# 47:	learn: 0.4149769	total: 413ms	remaining: 4.1s
# 48:	learn: 0.4137884	total: 422ms	remaining: 4.1s
# 49:	learn: 0.4121486	total: 431ms	remaining: 4.09s
# 50:	learn: 0.4107164	total: 439ms	remaining: 4.08s
# 51:	learn: 0.4089621	total: 448ms	remaining: 4.08s
# 52:	learn: 0.4075887	total: 457ms	remaining: 4.07s
# 53:	learn: 0.4060829	total: 466ms	remaining: 4.06s
# 54:	learn: 0.4046213	total: 475ms	remaining: 4.06s
# 55:	learn: 0.4031478	total: 485ms	remaining: 4.06s
# 56:	learn: 0.4018430	total: 494ms	remaining: 4.06s
# 57:	learn: 0.4003753	total: 504ms	remaining: 4.06s
# 58:	learn: 0.3988441	total: 513ms	remaining: 4.05s
# 59:	learn: 0.3975521	total: 522ms	remaining: 4.05s
# 60:	learn: 0.3957901	total: 532ms	remaining: 4.05s
# 61:	learn: 0.3942462	total: 541ms	remaining: 4.04s
# 62:	learn: 0.3930411	total: 550ms	remaining: 4.04s
# 63:	learn: 0.3918064	total: 560ms	remaining: 4.03s
# 64:	learn: 0.3908084	total: 570ms	remaining: 4.03s
# 65:	learn: 0.3894541	total: 579ms	remaining: 4.03s
# 66:	learn: 0.3876093	total: 588ms	remaining: 4.02s
# 67:	learn: 0.3862200	total: 597ms	remaining: 4.01s
# 68:	learn: 0.3848167	total: 607ms	remaining: 4.01s
# 69:	learn: 0.3834008	total: 616ms	remaining: 4s
# 70:	learn: 0.3828771	total: 617ms	remaining: 3.94s
# 71:	learn: 0.3817407	total: 626ms	remaining: 3.94s
# 72:	learn: 0.3803660	total: 636ms	remaining: 3.94s
# 73:	learn: 0.3790282	total: 644ms	remaining: 3.93s
# 74:	learn: 0.3778395	total: 654ms	remaining: 3.92s
# 75:	learn: 0.3767493	total: 663ms	remaining: 3.92s
# 76:	learn: 0.3756107	total: 672ms	remaining: 3.91s
# 77:	learn: 0.3747209	total: 682ms	remaining: 3.91s
# 78:	learn: 0.3736349	total: 691ms	remaining: 3.9s
# 79:	learn: 0.3722388	total: 701ms	remaining: 3.9s
# 80:	learn: 0.3711328	total: 709ms	remaining: 3.89s
# 81:	learn: 0.3700167	total: 719ms	remaining: 3.88s
# 82:	learn: 0.3690059	total: 728ms	remaining: 3.88s
# 83:	learn: 0.3678374	total: 737ms	remaining: 3.87s
# 84:	learn: 0.3666247	total: 746ms	remaining: 3.86s
# 85:	learn: 0.3653365	total: 755ms	remaining: 3.85s
# 86:	learn: 0.3638481	total: 765ms	remaining: 3.85s
# 87:	learn: 0.3628295	total: 774ms	remaining: 3.84s
# 88:	learn: 0.3615789	total: 783ms	remaining: 3.83s
# 89:	learn: 0.3606817	total: 792ms	remaining: 3.83s
# 90:	learn: 0.3594639	total: 801ms	remaining: 3.82s
# 91:	learn: 0.3581852	total: 809ms	remaining: 3.81s
# 92:	learn: 0.3572341	total: 818ms	remaining: 3.8s
# 93:	learn: 0.3560278	total: 828ms	remaining: 3.8s
# 94:	learn: 0.3549224	total: 837ms	remaining: 3.79s
# 95:	learn: 0.3541141	total: 846ms	remaining: 3.78s
# 96:	learn: 0.3530586	total: 856ms	remaining: 3.77s
# 97:	learn: 0.3520115	total: 865ms	remaining: 3.77s
# 98:	learn: 0.3507981	total: 875ms	remaining: 3.77s
# 99:	learn: 0.3495685	total: 884ms	remaining: 3.76s
# 100:	learn: 0.3488476	total: 894ms	remaining: 3.75s
# 101:	learn: 0.3476972	total: 904ms	remaining: 3.75s
# 102:	learn: 0.3464461	total: 913ms	remaining: 3.74s
# 103:	learn: 0.3455998	total: 922ms	remaining: 3.73s
# 104:	learn: 0.3445937	total: 931ms	remaining: 3.73s
# 105:	learn: 0.3436332	total: 941ms	remaining: 3.72s
# 106:	learn: 0.3425628	total: 951ms	remaining: 3.71s
# 107:	learn: 0.3415627	total: 961ms	remaining: 3.71s
# 108:	learn: 0.3403913	total: 971ms	remaining: 3.71s
# 109:	learn: 0.3393775	total: 981ms	remaining: 3.7s
# 110:	learn: 0.3383729	total: 990ms	remaining: 3.69s
# 111:	learn: 0.3373664	total: 999ms	remaining: 3.69s
# 112:	learn: 0.3363159	total: 1.01s	remaining: 3.68s
# 113:	learn: 0.3351448	total: 1.02s	remaining: 3.67s
# 114:	learn: 0.3341130	total: 1.03s	remaining: 3.66s
# 115:	learn: 0.3329253	total: 1.03s	remaining: 3.65s
# 116:	learn: 0.3318849	total: 1.04s	remaining: 3.64s
# 117:	learn: 0.3306901	total: 1.05s	remaining: 3.63s
# 118:	learn: 0.3299095	total: 1.06s	remaining: 3.62s
# 119:	learn: 0.3289189	total: 1.07s	remaining: 3.61s
# 120:	learn: 0.3279799	total: 1.08s	remaining: 3.6s
# 121:	learn: 0.3270484	total: 1.09s	remaining: 3.59s
# 122:	learn: 0.3264143	total: 1.1s	remaining: 3.58s
# 123:	learn: 0.3254538	total: 1.11s	remaining: 3.58s
# 124:	learn: 0.3245062	total: 1.12s	remaining: 3.57s
# 125:	learn: 0.3237209	total: 1.13s	remaining: 3.56s
# 126:	learn: 0.3229046	total: 1.13s	remaining: 3.56s
# 127:	learn: 0.3222037	total: 1.14s	remaining: 3.54s
# 128:	learn: 0.3212127	total: 1.15s	remaining: 3.54s
# 129:	learn: 0.3203260	total: 1.16s	remaining: 3.53s
# 130:	learn: 0.3194345	total: 1.17s	remaining: 3.52s
# 131:	learn: 0.3186666	total: 1.18s	remaining: 3.51s
# 132:	learn: 0.3177342	total: 1.19s	remaining: 3.5s
# 133:	learn: 0.3167579	total: 1.2s	remaining: 3.49s
# 134:	learn: 0.3159159	total: 1.21s	remaining: 3.48s
# 135:	learn: 0.3148123	total: 1.21s	remaining: 3.47s
# 136:	learn: 0.3139955	total: 1.22s	remaining: 3.46s
# 137:	learn: 0.3133006	total: 1.23s	remaining: 3.46s
# 138:	learn: 0.3122653	total: 1.24s	remaining: 3.45s
# 139:	learn: 0.3114378	total: 1.25s	remaining: 3.44s
# 140:	learn: 0.3105914	total: 1.26s	remaining: 3.43s
# 141:	learn: 0.3098080	total: 1.27s	remaining: 3.42s
# 142:	learn: 0.3089939	total: 1.28s	remaining: 3.41s
# 143:	learn: 0.3077985	total: 1.29s	remaining: 3.4s
# 144:	learn: 0.3071110	total: 1.29s	remaining: 3.4s
# 145:	learn: 0.3061395	total: 1.3s	remaining: 3.39s
# 146:	learn: 0.3054130	total: 1.31s	remaining: 3.38s
# 147:	learn: 0.3048280	total: 1.32s	remaining: 3.37s
# 148:	learn: 0.3042899	total: 1.33s	remaining: 3.36s
# 149:	learn: 0.3031750	total: 1.35s	remaining: 3.37s
# 150:	learn: 0.3025157	total: 1.36s	remaining: 3.36s
# 151:	learn: 0.3017719	total: 1.37s	remaining: 3.37s
# 152:	learn: 0.3010993	total: 1.38s	remaining: 3.36s
# 153:	learn: 0.3002828	total: 1.4s	remaining: 3.37s
# 154:	learn: 0.2997305	total: 1.41s	remaining: 3.36s
# 155:	learn: 0.2989105	total: 1.42s	remaining: 3.35s
# 156:	learn: 0.2982014	total: 1.43s	remaining: 3.34s
# 157:	learn: 0.2972963	total: 1.44s	remaining: 3.33s
# 158:	learn: 0.2965583	total: 1.44s	remaining: 3.32s
# 159:	learn: 0.2959807	total: 1.45s	remaining: 3.31s
# 160:	learn: 0.2952603	total: 1.46s	remaining: 3.31s
# 161:	learn: 0.2944544	total: 1.47s	remaining: 3.29s
# 162:	learn: 0.2939493	total: 1.48s	remaining: 3.29s
# 163:	learn: 0.2932859	total: 1.49s	remaining: 3.28s
# 164:	learn: 0.2924197	total: 1.5s	remaining: 3.27s
# 165:	learn: 0.2919425	total: 1.51s	remaining: 3.26s
# 166:	learn: 0.2910152	total: 1.52s	remaining: 3.25s
# 167:	learn: 0.2901879	total: 1.52s	remaining: 3.24s
# 168:	learn: 0.2894332	total: 1.53s	remaining: 3.23s
# 169:	learn: 0.2886235	total: 1.54s	remaining: 3.23s
# 170:	learn: 0.2879154	total: 1.55s	remaining: 3.22s
# 171:	learn: 0.2874370	total: 1.56s	remaining: 3.21s
# 172:	learn: 0.2867284	total: 1.57s	remaining: 3.2s
# 173:	learn: 0.2857539	total: 1.58s	remaining: 3.19s
# 174:	learn: 0.2849446	total: 1.59s	remaining: 3.17s
# 175:	learn: 0.2842460	total: 1.6s	remaining: 3.17s
# 176:	learn: 0.2834945	total: 1.6s	remaining: 3.15s
# 177:	learn: 0.2829060	total: 1.61s	remaining: 3.15s
# 178:	learn: 0.2823439	total: 1.62s	remaining: 3.14s
# 179:	learn: 0.2817549	total: 1.63s	remaining: 3.13s
# 180:	learn: 0.2808602	total: 1.64s	remaining: 3.12s
# 181:	learn: 0.2801323	total: 1.65s	remaining: 3.11s
# 182:	learn: 0.2793731	total: 1.66s	remaining: 3.1s
# 183:	learn: 0.2787183	total: 1.67s	remaining: 3.09s
# 184:	learn: 0.2781647	total: 1.68s	remaining: 3.08s
# 185:	learn: 0.2774590	total: 1.69s	remaining: 3.07s
# 186:	learn: 0.2768389	total: 1.69s	remaining: 3.06s
# 187:	learn: 0.2761678	total: 1.7s	remaining: 3.05s
# 188:	learn: 0.2756114	total: 1.71s	remaining: 3.04s
# 189:	learn: 0.2750556	total: 1.72s	remaining: 3.03s
# 190:	learn: 0.2743312	total: 1.73s	remaining: 3.02s
# 191:	learn: 0.2735325	total: 1.74s	remaining: 3.02s
# 192:	learn: 0.2729617	total: 1.75s	remaining: 3.01s
# 193:	learn: 0.2723538	total: 1.76s	remaining: 3s
# 194:	learn: 0.2717122	total: 1.76s	remaining: 2.99s
# 195:	learn: 0.2711820	total: 1.77s	remaining: 2.98s
# 196:	learn: 0.2705599	total: 1.78s	remaining: 2.97s
# 197:	learn: 0.2701924	total: 1.79s	remaining: 2.96s
# 198:	learn: 0.2694973	total: 1.8s	remaining: 2.95s
# 199:	learn: 0.2688400	total: 1.81s	remaining: 2.94s
# 200:	learn: 0.2685146	total: 1.82s	remaining: 2.93s
# 201:	learn: 0.2679044	total: 1.83s	remaining: 2.92s
# 202:	learn: 0.2673768	total: 1.84s	remaining: 2.91s
# 203:	learn: 0.2665975	total: 1.85s	remaining: 2.9s
# 204:	learn: 0.2659408	total: 1.85s	remaining: 2.9s
# 205:	learn: 0.2653452	total: 1.86s	remaining: 2.89s
# 206:	learn: 0.2649195	total: 1.87s	remaining: 2.88s
# 207:	learn: 0.2640958	total: 1.88s	remaining: 2.87s
# 208:	learn: 0.2634669	total: 1.89s	remaining: 2.86s
# 209:	learn: 0.2627375	total: 1.9s	remaining: 2.85s
# 210:	learn: 0.2620969	total: 1.91s	remaining: 2.84s
# 211:	learn: 0.2613661	total: 1.92s	remaining: 2.83s
# 212:	learn: 0.2607332	total: 1.93s	remaining: 2.82s
# 213:	learn: 0.2602281	total: 1.93s	remaining: 2.81s
# 214:	learn: 0.2595581	total: 1.94s	remaining: 2.8s
# 215:	learn: 0.2588973	total: 1.95s	remaining: 2.79s
# 216:	learn: 0.2583023	total: 1.96s	remaining: 2.78s
# 217:	learn: 0.2578531	total: 1.97s	remaining: 2.77s
# 218:	learn: 0.2572735	total: 1.98s	remaining: 2.76s
# 219:	learn: 0.2565421	total: 1.99s	remaining: 2.75s
# 220:	learn: 0.2560375	total: 2s	remaining: 2.74s
# 221:	learn: 0.2554006	total: 2s	remaining: 2.73s
# 222:	learn: 0.2549319	total: 2.01s	remaining: 2.73s
# 223:	learn: 0.2543402	total: 2.02s	remaining: 2.72s
# 224:	learn: 0.2538316	total: 2.03s	remaining: 2.71s
# 225:	learn: 0.2531187	total: 2.04s	remaining: 2.7s
# 226:	learn: 0.2526899	total: 2.05s	remaining: 2.69s
# 227:	learn: 0.2520942	total: 2.06s	remaining: 2.68s
# 228:	learn: 0.2516530	total: 2.07s	remaining: 2.67s
# 229:	learn: 0.2510400	total: 2.08s	remaining: 2.66s
# 230:	learn: 0.2503062	total: 2.09s	remaining: 2.66s
# 231:	learn: 0.2499426	total: 2.1s	remaining: 2.65s
# 232:	learn: 0.2493746	total: 2.1s	remaining: 2.64s
# 233:	learn: 0.2488322	total: 2.11s	remaining: 2.63s
# 234:	learn: 0.2483998	total: 2.12s	remaining: 2.62s
# 235:	learn: 0.2478814	total: 2.13s	remaining: 2.61s
# 236:	learn: 0.2471966	total: 2.14s	remaining: 2.6s
# 237:	learn: 0.2467270	total: 2.15s	remaining: 2.59s
# 238:	learn: 0.2461901	total: 2.16s	remaining: 2.58s
# 239:	learn: 0.2456530	total: 2.17s	remaining: 2.57s
# 240:	learn: 0.2453565	total: 2.17s	remaining: 2.56s
# 241:	learn: 0.2449176	total: 2.18s	remaining: 2.56s
# 242:	learn: 0.2444713	total: 2.19s	remaining: 2.54s
# 243:	learn: 0.2439673	total: 2.2s	remaining: 2.54s
# 244:	learn: 0.2437250	total: 2.21s	remaining: 2.53s
# 245:	learn: 0.2431499	total: 2.22s	remaining: 2.52s
# 246:	learn: 0.2426730	total: 2.23s	remaining: 2.51s
# 247:	learn: 0.2423783	total: 2.24s	remaining: 2.5s
# 248:	learn: 0.2418976	total: 2.25s	remaining: 2.49s
# 249:	learn: 0.2413118	total: 2.25s	remaining: 2.48s
# 250:	learn: 0.2406903	total: 2.26s	remaining: 2.47s
# 251:	learn: 0.2403797	total: 2.27s	remaining: 2.46s
# 252:	learn: 0.2397562	total: 2.28s	remaining: 2.45s
# 253:	learn: 0.2391669	total: 2.29s	remaining: 2.44s
# 254:	learn: 0.2386470	total: 2.3s	remaining: 2.43s
# 255:	learn: 0.2383386	total: 2.31s	remaining: 2.42s
# 256:	learn: 0.2379360	total: 2.32s	remaining: 2.42s
# 257:	learn: 0.2374334	total: 2.33s	remaining: 2.41s
# 258:	learn: 0.2369060	total: 2.34s	remaining: 2.4s
# 259:	learn: 0.2364002	total: 2.35s	remaining: 2.4s
# 260:	learn: 0.2358363	total: 2.36s	remaining: 2.38s
# 261:	learn: 0.2352197	total: 2.37s	remaining: 2.38s
# 262:	learn: 0.2347454	total: 2.38s	remaining: 2.37s
# 263:	learn: 0.2340760	total: 2.39s	remaining: 2.36s
# 264:	learn: 0.2335778	total: 2.4s	remaining: 2.35s
# 265:	learn: 0.2330903	total: 2.41s	remaining: 2.34s
# 266:	learn: 0.2327196	total: 2.42s	remaining: 2.33s
# 267:	learn: 0.2320915	total: 2.42s	remaining: 2.33s
# 268:	learn: 0.2314990	total: 2.43s	remaining: 2.32s
# 269:	learn: 0.2310084	total: 2.44s	remaining: 2.31s
# 270:	learn: 0.2306589	total: 2.45s	remaining: 2.3s
# 271:	learn: 0.2302349	total: 2.46s	remaining: 2.29s
# 272:	learn: 0.2297458	total: 2.47s	remaining: 2.28s
# 273:	learn: 0.2291532	total: 2.48s	remaining: 2.27s
# 274:	learn: 0.2287868	total: 2.49s	remaining: 2.27s
# 275:	learn: 0.2282975	total: 2.5s	remaining: 2.26s
# 276:	learn: 0.2280209	total: 2.52s	remaining: 2.25s
# 277:	learn: 0.2276378	total: 2.53s	remaining: 2.25s
# 278:	learn: 0.2271697	total: 2.54s	remaining: 2.24s
# 279:	learn: 0.2266336	total: 2.55s	remaining: 2.23s
# 280:	learn: 0.2260530	total: 2.56s	remaining: 2.22s
# 281:	learn: 0.2254445	total: 2.57s	remaining: 2.21s
# 282:	learn: 0.2248841	total: 2.58s	remaining: 2.21s
# 283:	learn: 0.2242719	total: 2.59s	remaining: 2.2s
# 284:	learn: 0.2236487	total: 2.6s	remaining: 2.19s
# 285:	learn: 0.2232043	total: 2.6s	remaining: 2.18s
# 286:	learn: 0.2226552	total: 2.61s	remaining: 2.17s
# 287:	learn: 0.2220991	total: 2.62s	remaining: 2.16s
# 288:	learn: 0.2217194	total: 2.63s	remaining: 2.15s
# 289:	learn: 0.2211482	total: 2.64s	remaining: 2.14s
# 290:	learn: 0.2207112	total: 2.65s	remaining: 2.13s
# 291:	learn: 0.2202509	total: 2.66s	remaining: 2.12s
# 292:	learn: 0.2197261	total: 2.67s	remaining: 2.11s
# 293:	learn: 0.2194462	total: 2.67s	remaining: 2.1s
# 294:	learn: 0.2190491	total: 2.68s	remaining: 2.09s
# 295:	learn: 0.2185849	total: 2.69s	remaining: 2.08s
# 296:	learn: 0.2183421	total: 2.7s	remaining: 2.07s
# 297:	learn: 0.2180018	total: 2.71s	remaining: 2.06s
# 298:	learn: 0.2175882	total: 2.72s	remaining: 2.05s
# 299:	learn: 0.2173704	total: 2.73s	remaining: 2.04s
# 300:	learn: 0.2167534	total: 2.74s	remaining: 2.04s
# 301:	learn: 0.2162655	total: 2.75s	remaining: 2.03s
# 302:	learn: 0.2157907	total: 2.76s	remaining: 2.02s
# 303:	learn: 0.2154280	total: 2.77s	remaining: 2.01s
# 304:	learn: 0.2149735	total: 2.78s	remaining: 2s
# 305:	learn: 0.2145468	total: 2.79s	remaining: 1.99s
# 306:	learn: 0.2142178	total: 2.79s	remaining: 1.99s
# 307:	learn: 0.2138851	total: 2.8s	remaining: 1.98s
# 308:	learn: 0.2134366	total: 2.81s	remaining: 1.97s
# 309:	learn: 0.2129094	total: 2.82s	remaining: 1.96s
# 310:	learn: 0.2123113	total: 2.83s	remaining: 1.95s
# 311:	learn: 0.2116979	total: 2.84s	remaining: 1.94s
# 312:	learn: 0.2114083	total: 2.85s	remaining: 1.93s
# 313:	learn: 0.2108987	total: 2.86s	remaining: 1.92s
# 314:	learn: 0.2102911	total: 2.87s	remaining: 1.91s
# 315:	learn: 0.2098611	total: 2.87s	remaining: 1.9s
# 316:	learn: 0.2095235	total: 2.88s	remaining: 1.89s
# 317:	learn: 0.2091633	total: 2.89s	remaining: 1.88s
# 318:	learn: 0.2088872	total: 2.9s	remaining: 1.87s
# 319:	learn: 0.2086966	total: 2.9s	remaining: 1.86s
# 320:	learn: 0.2080807	total: 2.91s	remaining: 1.85s
# 321:	learn: 0.2076745	total: 2.92s	remaining: 1.84s
# 322:	learn: 0.2071877	total: 2.93s	remaining: 1.83s
# 323:	learn: 0.2068395	total: 2.94s	remaining: 1.82s
# 324:	learn: 0.2064548	total: 2.95s	remaining: 1.81s
# 325:	learn: 0.2060653	total: 2.96s	remaining: 1.8s
# 326:	learn: 0.2056936	total: 2.97s	remaining: 1.8s
# 327:	learn: 0.2053518	total: 2.98s	remaining: 1.79s
# 328:	learn: 0.2050142	total: 2.99s	remaining: 1.78s
# 329:	learn: 0.2047195	total: 3s	remaining: 1.77s
# 330:	learn: 0.2042702	total: 3s	remaining: 1.76s
# 331:	learn: 0.2039191	total: 3.02s	remaining: 1.75s
# 332:	learn: 0.2035234	total: 3.02s	remaining: 1.74s
# 333:	learn: 0.2032094	total: 3.03s	remaining: 1.73s
# 334:	learn: 0.2028261	total: 3.04s	remaining: 1.73s
# 335:	learn: 0.2023328	total: 3.05s	remaining: 1.72s
# 336:	learn: 0.2018795	total: 3.06s	remaining: 1.71s
# 337:	learn: 0.2015400	total: 3.07s	remaining: 1.7s
# 338:	learn: 0.2010443	total: 3.08s	remaining: 1.69s
# 339:	learn: 0.2004355	total: 3.09s	remaining: 1.68s
# 340:	learn: 0.1999735	total: 3.1s	remaining: 1.67s
# 341:	learn: 0.1995771	total: 3.1s	remaining: 1.66s
# 342:	learn: 0.1992591	total: 3.11s	remaining: 1.65s
# 343:	learn: 0.1987672	total: 3.12s	remaining: 1.64s
# 344:	learn: 0.1984362	total: 3.13s	remaining: 1.63s
# 345:	learn: 0.1981011	total: 3.14s	remaining: 1.62s
# 346:	learn: 0.1978166	total: 3.15s	remaining: 1.61s
# 347:	learn: 0.1974379	total: 3.16s	remaining: 1.61s
# 348:	learn: 0.1970860	total: 3.17s	remaining: 1.6s
# 349:	learn: 0.1966887	total: 3.17s	remaining: 1.59s
# 350:	learn: 0.1963403	total: 3.18s	remaining: 1.58s
# 351:	learn: 0.1958839	total: 3.19s	remaining: 1.57s
# 352:	learn: 0.1955288	total: 3.2s	remaining: 1.56s
# 353:	learn: 0.1952618	total: 3.21s	remaining: 1.55s
# 354:	learn: 0.1947942	total: 3.22s	remaining: 1.54s
# 355:	learn: 0.1942397	total: 3.23s	remaining: 1.53s
# 356:	learn: 0.1937866	total: 3.24s	remaining: 1.52s
# 357:	learn: 0.1934877	total: 3.25s	remaining: 1.51s
# 358:	learn: 0.1931245	total: 3.26s	remaining: 1.51s
# 359:	learn: 0.1927433	total: 3.27s	remaining: 1.5s
# 360:	learn: 0.1923758	total: 3.28s	remaining: 1.49s
# 361:	learn: 0.1919652	total: 3.29s	remaining: 1.48s
# 362:	learn: 0.1915749	total: 3.3s	remaining: 1.47s
# 363:	learn: 0.1911944	total: 3.31s	remaining: 1.46s
# 364:	learn: 0.1908195	total: 3.32s	remaining: 1.46s
# 365:	learn: 0.1905190	total: 3.34s	remaining: 1.45s
# 366:	learn: 0.1901295	total: 3.35s	remaining: 1.44s
# 367:	learn: 0.1898128	total: 3.36s	remaining: 1.43s
# 368:	learn: 0.1894375	total: 3.37s	remaining: 1.43s
# 369:	learn: 0.1889975	total: 3.38s	remaining: 1.42s
# 370:	learn: 0.1886242	total: 3.39s	remaining: 1.41s
# 371:	learn: 0.1881482	total: 3.4s	remaining: 1.4s
# 372:	learn: 0.1877695	total: 3.41s	remaining: 1.39s
# 373:	learn: 0.1874395	total: 3.42s	remaining: 1.38s
# 374:	learn: 0.1870900	total: 3.43s	remaining: 1.37s
# 375:	learn: 0.1866368	total: 3.44s	remaining: 1.36s
# 376:	learn: 0.1860671	total: 3.45s	remaining: 1.35s
# 377:	learn: 0.1856760	total: 3.46s	remaining: 1.34s
# 378:	learn: 0.1850504	total: 3.46s	remaining: 1.33s
# 379:	learn: 0.1843715	total: 3.47s	remaining: 1.32s
# 380:	learn: 0.1840268	total: 3.48s	remaining: 1.32s
# 381:	learn: 0.1836180	total: 3.49s	remaining: 1.31s
# 382:	learn: 0.1831942	total: 3.5s	remaining: 1.3s
# 383:	learn: 0.1829260	total: 3.51s	remaining: 1.29s
# 384:	learn: 0.1825511	total: 3.52s	remaining: 1.28s
# 385:	learn: 0.1820128	total: 3.53s	remaining: 1.27s
# 386:	learn: 0.1816628	total: 3.54s	remaining: 1.26s
# 387:	learn: 0.1813096	total: 3.54s	remaining: 1.25s
# 388:	learn: 0.1809673	total: 3.55s	remaining: 1.24s
# 389:	learn: 0.1805782	total: 3.56s	remaining: 1.23s
# 390:	learn: 0.1804017	total: 3.57s	remaining: 1.22s
# 391:	learn: 0.1800452	total: 3.58s	remaining: 1.21s
# 392:	learn: 0.1797143	total: 3.59s	remaining: 1.2s
# 393:	learn: 0.1793795	total: 3.6s	remaining: 1.2s
# 394:	learn: 0.1790293	total: 3.6s	remaining: 1.19s
# 395:	learn: 0.1786555	total: 3.61s	remaining: 1.18s
# 396:	learn: 0.1783113	total: 3.62s	remaining: 1.17s
# 397:	learn: 0.1780376	total: 3.63s	remaining: 1.16s
# 398:	learn: 0.1775746	total: 3.64s	remaining: 1.15s
# 399:	learn: 0.1772651	total: 3.65s	remaining: 1.14s
# 400:	learn: 0.1769997	total: 3.66s	remaining: 1.13s
# 401:	learn: 0.1767804	total: 3.66s	remaining: 1.12s
# 402:	learn: 0.1764349	total: 3.67s	remaining: 1.11s
# 403:	learn: 0.1761616	total: 3.68s	remaining: 1.1s
# 404:	learn: 0.1756998	total: 3.69s	remaining: 1.09s
# 405:	learn: 0.1752327	total: 3.7s	remaining: 1.08s
# 406:	learn: 0.1748606	total: 3.71s	remaining: 1.07s
# 407:	learn: 0.1745306	total: 3.71s	remaining: 1.06s
# 408:	learn: 0.1741457	total: 3.72s	remaining: 1.06s
# 409:	learn: 0.1739327	total: 3.73s	remaining: 1.05s
# 410:	learn: 0.1736340	total: 3.74s	remaining: 1.04s
# 411:	learn: 0.1732221	total: 3.75s	remaining: 1.03s
# 412:	learn: 0.1728746	total: 3.76s	remaining: 1.02s
# 413:	learn: 0.1724518	total: 3.77s	remaining: 1.01s
# 414:	learn: 0.1723000	total: 3.77s	remaining: 1000ms
# 415:	learn: 0.1718830	total: 3.78s	remaining: 990ms
# 416:	learn: 0.1715040	total: 3.79s	remaining: 981ms
# 417:	learn: 0.1710743	total: 3.8s	remaining: 972ms
# 418:	learn: 0.1708818	total: 3.81s	remaining: 963ms
# 419:	learn: 0.1705636	total: 3.81s	remaining: 953ms
# 420:	learn: 0.1701437	total: 3.82s	remaining: 944ms
# 421:	learn: 0.1699137	total: 3.83s	remaining: 935ms
# 422:	learn: 0.1695951	total: 3.84s	remaining: 926ms
# 423:	learn: 0.1693247	total: 3.85s	remaining: 917ms
# 424:	learn: 0.1689753	total: 3.86s	remaining: 907ms
# 425:	learn: 0.1686610	total: 3.86s	remaining: 898ms
# 426:	learn: 0.1682540	total: 3.87s	remaining: 889ms
# 427:	learn: 0.1680673	total: 3.88s	remaining: 880ms
# 428:	learn: 0.1677173	total: 3.89s	remaining: 870ms
# 429:	learn: 0.1675125	total: 3.9s	remaining: 861ms
# 430:	learn: 0.1671113	total: 3.91s	remaining: 852ms
# 431:	learn: 0.1668273	total: 3.91s	remaining: 843ms
# 432:	learn: 0.1664788	total: 3.92s	remaining: 834ms
# 433:	learn: 0.1661491	total: 3.93s	remaining: 824ms
# 434:	learn: 0.1656963	total: 3.94s	remaining: 815ms
# 435:	learn: 0.1654594	total: 3.95s	remaining: 806ms
# 436:	learn: 0.1650565	total: 3.96s	remaining: 797ms
# 437:	learn: 0.1647343	total: 3.97s	remaining: 788ms
# 438:	learn: 0.1645149	total: 3.97s	remaining: 779ms
# 439:	learn: 0.1642743	total: 3.98s	remaining: 769ms
# 440:	learn: 0.1642612	total: 3.98s	remaining: 759ms
# 441:	learn: 0.1638628	total: 3.99s	remaining: 750ms
# 442:	learn: 0.1635875	total: 4s	remaining: 741ms
# 443:	learn: 0.1633763	total: 4.01s	remaining: 732ms
# 444:	learn: 0.1631868	total: 4.02s	remaining: 722ms
# 445:	learn: 0.1626899	total: 4.03s	remaining: 713ms
# 446:	learn: 0.1623651	total: 4.04s	remaining: 704ms
# 447:	learn: 0.1619470	total: 4.04s	remaining: 695ms
# 448:	learn: 0.1618348	total: 4.05s	remaining: 686ms
# 449:	learn: 0.1615491	total: 4.06s	remaining: 677ms
# 450:	learn: 0.1611386	total: 4.07s	remaining: 668ms
# 451:	learn: 0.1607723	total: 4.08s	remaining: 659ms
# 452:	learn: 0.1604904	total: 4.09s	remaining: 650ms
# 453:	learn: 0.1603019	total: 4.1s	remaining: 641ms
# 454:	learn: 0.1600854	total: 4.1s	remaining: 631ms
# 455:	learn: 0.1596574	total: 4.11s	remaining: 622ms
# 456:	learn: 0.1593527	total: 4.12s	remaining: 613ms
# 457:	learn: 0.1589842	total: 4.13s	remaining: 604ms
# 458:	learn: 0.1586274	total: 4.14s	remaining: 595ms
# 459:	learn: 0.1584065	total: 4.14s	remaining: 586ms
# 460:	learn: 0.1580706	total: 4.15s	remaining: 577ms
# 461:	learn: 0.1577644	total: 4.16s	remaining: 568ms
# 462:	learn: 0.1573031	total: 4.17s	remaining: 559ms
# 463:	learn: 0.1570854	total: 4.18s	remaining: 550ms
# 464:	learn: 0.1566155	total: 4.19s	remaining: 541ms
# 465:	learn: 0.1563899	total: 4.2s	remaining: 531ms
# 466:	learn: 0.1560961	total: 4.21s	remaining: 522ms
# 467:	learn: 0.1558371	total: 4.21s	remaining: 513ms
# 468:	learn: 0.1554104	total: 4.22s	remaining: 504ms
# 469:	learn: 0.1552044	total: 4.23s	remaining: 495ms
# 470:	learn: 0.1549121	total: 4.24s	remaining: 487ms
# 471:	learn: 0.1545859	total: 4.25s	remaining: 478ms
# 472:	learn: 0.1543506	total: 4.26s	remaining: 469ms
# 473:	learn: 0.1541327	total: 4.27s	remaining: 460ms
# 474:	learn: 0.1538468	total: 4.28s	remaining: 451ms
# 475:	learn: 0.1535281	total: 4.3s	remaining: 442ms
# 476:	learn: 0.1532250	total: 4.31s	remaining: 434ms
# 477:	learn: 0.1528642	total: 4.32s	remaining: 425ms
# 478:	learn: 0.1525426	total: 4.33s	remaining: 416ms
# 479:	learn: 0.1521244	total: 4.35s	remaining: 408ms
# 480:	learn: 0.1519210	total: 4.36s	remaining: 399ms
# 481:	learn: 0.1517492	total: 4.37s	remaining: 389ms
# 482:	learn: 0.1513798	total: 4.37s	remaining: 380ms
# 483:	learn: 0.1510740	total: 4.38s	remaining: 371ms
# 484:	learn: 0.1508648	total: 4.39s	remaining: 362ms
# 485:	learn: 0.1506179	total: 4.4s	remaining: 353ms
# 486:	learn: 0.1503398	total: 4.41s	remaining: 344ms
# 487:	learn: 0.1500604	total: 4.41s	remaining: 335ms
# 488:	learn: 0.1498157	total: 4.42s	remaining: 326ms
# 489:	learn: 0.1495581	total: 4.43s	remaining: 317ms
# 490:	learn: 0.1490920	total: 4.44s	remaining: 307ms
# 491:	learn: 0.1488146	total: 4.45s	remaining: 298ms
# 492:	learn: 0.1485358	total: 4.46s	remaining: 289ms
# 493:	learn: 0.1482064	total: 4.47s	remaining: 280ms
# 494:	learn: 0.1480044	total: 4.47s	remaining: 271ms
# 495:	learn: 0.1476963	total: 4.48s	remaining: 262ms
# 496:	learn: 0.1474388	total: 4.49s	remaining: 253ms
# 497:	learn: 0.1472912	total: 4.5s	remaining: 244ms
# 498:	learn: 0.1469816	total: 4.51s	remaining: 235ms
# 499:	learn: 0.1467252	total: 4.52s	remaining: 226ms
# 500:	learn: 0.1465781	total: 4.53s	remaining: 217ms
# 501:	learn: 0.1463159	total: 4.54s	remaining: 208ms
# 502:	learn: 0.1459949	total: 4.54s	remaining: 199ms
# 503:	learn: 0.1456464	total: 4.55s	remaining: 190ms
# 504:	learn: 0.1453875	total: 4.56s	remaining: 181ms
# 505:	learn: 0.1450911	total: 4.57s	remaining: 172ms
# 506:	learn: 0.1448829	total: 4.58s	remaining: 163ms
# 507:	learn: 0.1445700	total: 4.59s	remaining: 153ms
# 508:	learn: 0.1443749	total: 4.6s	remaining: 144ms
# 509:	learn: 0.1440779	total: 4.61s	remaining: 135ms
# 510:	learn: 0.1438183	total: 4.62s	remaining: 126ms
# 511:	learn: 0.1435586	total: 4.62s	remaining: 117ms
# 512:	learn: 0.1431839	total: 4.63s	remaining: 108ms
# 513:	learn: 0.1428450	total: 4.64s	remaining: 99.3ms
# 514:	learn: 0.1425357	total: 4.65s	remaining: 90.3ms
# 515:	learn: 0.1423092	total: 4.66s	remaining: 81.2ms
# 516:	learn: 0.1419821	total: 4.67s	remaining: 72.2ms
# 517:	learn: 0.1415479	total: 4.68s	remaining: 63.2ms
# 518:	learn: 0.1413037	total: 4.68s	remaining: 54.2ms
# 519:	learn: 0.1408758	total: 4.69s	remaining: 45.1ms
# 520:	learn: 0.1405241	total: 4.7s	remaining: 36.1ms
# 521:	learn: 0.1401848	total: 4.71s	remaining: 27.1ms
# 522:	learn: 0.1399064	total: 4.72s	remaining: 18ms
# 523:	learn: 0.1396022	total: 4.73s	remaining: 9.02ms
# 524:	learn: 0.1394135	total: 4.74s	remaining: 0us
# 	 -> Scored 0.178
#
# Validating on season 2018
# 0:	learn: 0.4978050	total: 12.8ms	remaining: 6.72s
# 1:	learn: 0.4958576	total: 24.3ms	remaining: 6.35s
# 2:	learn: 0.4941553	total: 35ms	remaining: 6.1s
# 3:	learn: 0.4922442	total: 45.1ms	remaining: 5.87s
# 4:	learn: 0.4900557	total: 55.3ms	remaining: 5.75s
# 5:	learn: 0.4881502	total: 65.8ms	remaining: 5.69s
# 6:	learn: 0.4863675	total: 76ms	remaining: 5.62s
# 7:	learn: 0.4844980	total: 86.7ms	remaining: 5.6s
# 8:	learn: 0.4822604	total: 96.8ms	remaining: 5.55s
# 9:	learn: 0.4804500	total: 107ms	remaining: 5.49s
# 10:	learn: 0.4787817	total: 117ms	remaining: 5.49s
# 11:	learn: 0.4772137	total: 128ms	remaining: 5.48s
# 12:	learn: 0.4754499	total: 138ms	remaining: 5.45s
# 13:	learn: 0.4739260	total: 149ms	remaining: 5.42s
# 14:	learn: 0.4722119	total: 159ms	remaining: 5.4s
# 15:	learn: 0.4707659	total: 168ms	remaining: 5.36s
# 16:	learn: 0.4691451	total: 180ms	remaining: 5.39s
# 17:	learn: 0.4675336	total: 195ms	remaining: 5.5s
# 18:	learn: 0.4659459	total: 211ms	remaining: 5.61s
# 19:	learn: 0.4641811	total: 225ms	remaining: 5.69s
# 20:	learn: 0.4626414	total: 237ms	remaining: 5.69s
# 21:	learn: 0.4609626	total: 253ms	remaining: 5.78s
# 22:	learn: 0.4595362	total: 266ms	remaining: 5.8s
# 23:	learn: 0.4581999	total: 276ms	remaining: 5.76s
# 24:	learn: 0.4570479	total: 286ms	remaining: 5.73s
# 25:	learn: 0.4555163	total: 297ms	remaining: 5.69s
# 26:	learn: 0.4539567	total: 307ms	remaining: 5.66s
# 27:	learn: 0.4521991	total: 316ms	remaining: 5.62s
# 28:	learn: 0.4506259	total: 326ms	remaining: 5.57s
# 29:	learn: 0.4495520	total: 328ms	remaining: 5.4s
# 30:	learn: 0.4482648	total: 337ms	remaining: 5.38s
# 31:	learn: 0.4471154	total: 339ms	remaining: 5.22s
# 32:	learn: 0.4457084	total: 348ms	remaining: 5.19s
# 33:	learn: 0.4442131	total: 357ms	remaining: 5.16s
# 34:	learn: 0.4431012	total: 367ms	remaining: 5.14s
# 35:	learn: 0.4414871	total: 377ms	remaining: 5.12s
# 36:	learn: 0.4400925	total: 386ms	remaining: 5.09s
# 37:	learn: 0.4385475	total: 395ms	remaining: 5.07s
# 38:	learn: 0.4372019	total: 405ms	remaining: 5.05s
# 39:	learn: 0.4358110	total: 414ms	remaining: 5.02s
# 40:	learn: 0.4345396	total: 424ms	remaining: 5.01s
# 41:	learn: 0.4332291	total: 434ms	remaining: 4.99s
# 42:	learn: 0.4318716	total: 443ms	remaining: 4.96s
# 43:	learn: 0.4304884	total: 454ms	remaining: 4.96s
# 44:	learn: 0.4291217	total: 464ms	remaining: 4.95s
# 45:	learn: 0.4277783	total: 474ms	remaining: 4.93s
# 46:	learn: 0.4266200	total: 483ms	remaining: 4.91s
# 47:	learn: 0.4249376	total: 493ms	remaining: 4.9s
# 48:	learn: 0.4237219	total: 503ms	remaining: 4.88s
# 49:	learn: 0.4225117	total: 512ms	remaining: 4.87s
# 50:	learn: 0.4215054	total: 522ms	remaining: 4.85s
# 51:	learn: 0.4203324	total: 531ms	remaining: 4.83s
# 52:	learn: 0.4189084	total: 541ms	remaining: 4.82s
# 53:	learn: 0.4179628	total: 552ms	remaining: 4.81s
# 54:	learn: 0.4167108	total: 562ms	remaining: 4.8s
# 55:	learn: 0.4157489	total: 572ms	remaining: 4.79s
# 56:	learn: 0.4148901	total: 582ms	remaining: 4.78s
# 57:	learn: 0.4135692	total: 592ms	remaining: 4.77s
# 58:	learn: 0.4121401	total: 603ms	remaining: 4.76s
# 59:	learn: 0.4112744	total: 614ms	remaining: 4.76s
# 60:	learn: 0.4100379	total: 625ms	remaining: 4.75s
# 61:	learn: 0.4087133	total: 637ms	remaining: 4.76s
# 62:	learn: 0.4076890	total: 647ms	remaining: 4.74s
# 63:	learn: 0.4066895	total: 657ms	remaining: 4.73s
# 64:	learn: 0.4052276	total: 668ms	remaining: 4.72s
# 65:	learn: 0.4042065	total: 677ms	remaining: 4.71s
# 66:	learn: 0.4030445	total: 688ms	remaining: 4.7s
# 67:	learn: 0.4019789	total: 698ms	remaining: 4.69s
# 68:	learn: 0.4009847	total: 708ms	remaining: 4.68s
# 69:	learn: 0.3997647	total: 719ms	remaining: 4.67s
# 70:	learn: 0.3988260	total: 728ms	remaining: 4.66s
# 71:	learn: 0.3978917	total: 739ms	remaining: 4.65s
# 72:	learn: 0.3967941	total: 749ms	remaining: 4.64s
# 73:	learn: 0.3958423	total: 759ms	remaining: 4.62s
# 74:	learn: 0.3948738	total: 769ms	remaining: 4.61s
# 75:	learn: 0.3940999	total: 779ms	remaining: 4.6s
# 76:	learn: 0.3931632	total: 789ms	remaining: 4.59s
# 77:	learn: 0.3920769	total: 799ms	remaining: 4.58s
# 78:	learn: 0.3911762	total: 810ms	remaining: 4.57s
# 79:	learn: 0.3903773	total: 821ms	remaining: 4.56s
# 80:	learn: 0.3894941	total: 832ms	remaining: 4.56s
# 81:	learn: 0.3883450	total: 841ms	remaining: 4.54s
# 82:	learn: 0.3874000	total: 852ms	remaining: 4.54s
# 83:	learn: 0.3866450	total: 862ms	remaining: 4.53s
# 84:	learn: 0.3856059	total: 872ms	remaining: 4.51s
# 85:	learn: 0.3847975	total: 883ms	remaining: 4.51s
# 86:	learn: 0.3839096	total: 894ms	remaining: 4.5s
# 87:	learn: 0.3827805	total: 904ms	remaining: 4.49s
# 88:	learn: 0.3816404	total: 914ms	remaining: 4.48s
# 89:	learn: 0.3807727	total: 925ms	remaining: 4.47s
# 90:	learn: 0.3796071	total: 935ms	remaining: 4.46s
# 91:	learn: 0.3786717	total: 946ms	remaining: 4.45s
# 92:	learn: 0.3779565	total: 956ms	remaining: 4.44s
# 93:	learn: 0.3772751	total: 966ms	remaining: 4.43s
# 94:	learn: 0.3764753	total: 976ms	remaining: 4.42s
# 95:	learn: 0.3754909	total: 985ms	remaining: 4.4s
# 96:	learn: 0.3744968	total: 995ms	remaining: 4.39s
# 97:	learn: 0.3733797	total: 1s	remaining: 4.38s
# 98:	learn: 0.3725904	total: 1.01s	remaining: 4.37s
# 99:	learn: 0.3715149	total: 1.03s	remaining: 4.36s
# 100:	learn: 0.3708167	total: 1.04s	remaining: 4.35s
# 101:	learn: 0.3700747	total: 1.04s	remaining: 4.34s
# 102:	learn: 0.3691899	total: 1.05s	remaining: 4.33s
# 103:	learn: 0.3683026	total: 1.07s	remaining: 4.32s
# 104:	learn: 0.3676303	total: 1.08s	remaining: 4.3s
# 105:	learn: 0.3668502	total: 1.09s	remaining: 4.29s
# 106:	learn: 0.3660176	total: 1.1s	remaining: 4.28s
# 107:	learn: 0.3653633	total: 1.11s	remaining: 4.27s
# 108:	learn: 0.3646905	total: 1.12s	remaining: 4.26s
# 109:	learn: 0.3641607	total: 1.13s	remaining: 4.25s
# 110:	learn: 0.3632434	total: 1.14s	remaining: 4.24s
# 111:	learn: 0.3624114	total: 1.15s	remaining: 4.23s
# 112:	learn: 0.3619143	total: 1.16s	remaining: 4.22s
# 113:	learn: 0.3612753	total: 1.17s	remaining: 4.23s
# 114:	learn: 0.3605003	total: 1.19s	remaining: 4.23s
# 115:	learn: 0.3597976	total: 1.2s	remaining: 4.23s
# 116:	learn: 0.3587882	total: 1.21s	remaining: 4.23s
# 117:	learn: 0.3581700	total: 1.23s	remaining: 4.23s
# 118:	learn: 0.3574698	total: 1.24s	remaining: 4.23s
# 119:	learn: 0.3568861	total: 1.25s	remaining: 4.23s
# 120:	learn: 0.3563902	total: 1.27s	remaining: 4.23s
# 121:	learn: 0.3555162	total: 1.28s	remaining: 4.22s
# 122:	learn: 0.3546361	total: 1.29s	remaining: 4.22s
# 123:	learn: 0.3538387	total: 1.3s	remaining: 4.21s
# 124:	learn: 0.3530904	total: 1.31s	remaining: 4.2s
# 125:	learn: 0.3523646	total: 1.32s	remaining: 4.19s
# 126:	learn: 0.3516368	total: 1.33s	remaining: 4.18s
# 127:	learn: 0.3508610	total: 1.35s	remaining: 4.18s
# 128:	learn: 0.3499994	total: 1.36s	remaining: 4.17s
# 129:	learn: 0.3494476	total: 1.37s	remaining: 4.16s
# 130:	learn: 0.3487617	total: 1.38s	remaining: 4.14s
# 131:	learn: 0.3481069	total: 1.39s	remaining: 4.13s
# 132:	learn: 0.3477334	total: 1.4s	remaining: 4.12s
# 133:	learn: 0.3471637	total: 1.41s	remaining: 4.1s
# 134:	learn: 0.3464912	total: 1.42s	remaining: 4.09s
# 135:	learn: 0.3458461	total: 1.43s	remaining: 4.08s
# 136:	learn: 0.3452344	total: 1.44s	remaining: 4.06s
# 137:	learn: 0.3446868	total: 1.44s	remaining: 4.05s
# 138:	learn: 0.3438607	total: 1.45s	remaining: 4.04s
# 139:	learn: 0.3434132	total: 1.46s	remaining: 4.03s
# 140:	learn: 0.3429723	total: 1.47s	remaining: 4.01s
# 141:	learn: 0.3422213	total: 1.48s	remaining: 4s
# 142:	learn: 0.3413780	total: 1.49s	remaining: 3.99s
# 143:	learn: 0.3408433	total: 1.5s	remaining: 3.98s
# 144:	learn: 0.3404590	total: 1.51s	remaining: 3.96s
# 145:	learn: 0.3398975	total: 1.52s	remaining: 3.95s
# 146:	learn: 0.3392708	total: 1.53s	remaining: 3.94s
# 147:	learn: 0.3385573	total: 1.54s	remaining: 3.93s
# 148:	learn: 0.3379378	total: 1.55s	remaining: 3.92s
# 149:	learn: 0.3374111	total: 1.56s	remaining: 3.91s
# 150:	learn: 0.3369249	total: 1.57s	remaining: 3.9s
# 151:	learn: 0.3363709	total: 1.58s	remaining: 3.89s
# 152:	learn: 0.3354860	total: 1.59s	remaining: 3.88s
# 153:	learn: 0.3346736	total: 1.6s	remaining: 3.86s
# 154:	learn: 0.3340992	total: 1.61s	remaining: 3.85s
# 155:	learn: 0.3335337	total: 1.62s	remaining: 3.84s
# 156:	learn: 0.3329800	total: 1.63s	remaining: 3.83s
# 157:	learn: 0.3324350	total: 1.64s	remaining: 3.81s
# 158:	learn: 0.3320137	total: 1.65s	remaining: 3.79s
# 159:	learn: 0.3313737	total: 1.66s	remaining: 3.78s
# 160:	learn: 0.3308844	total: 1.67s	remaining: 3.77s
# 161:	learn: 0.3304441	total: 1.68s	remaining: 3.76s
# 162:	learn: 0.3299251	total: 1.69s	remaining: 3.75s
# 163:	learn: 0.3292074	total: 1.7s	remaining: 3.73s
# 164:	learn: 0.3287204	total: 1.71s	remaining: 3.72s
# 165:	learn: 0.3281619	total: 1.72s	remaining: 3.71s
# 166:	learn: 0.3276581	total: 1.73s	remaining: 3.7s
# 167:	learn: 0.3268957	total: 1.74s	remaining: 3.69s
# 168:	learn: 0.3264346	total: 1.75s	remaining: 3.68s
# 169:	learn: 0.3260055	total: 1.76s	remaining: 3.67s
# 170:	learn: 0.3256304	total: 1.77s	remaining: 3.66s
# 171:	learn: 0.3250217	total: 1.78s	remaining: 3.65s
# 172:	learn: 0.3244219	total: 1.79s	remaining: 3.64s
# 173:	learn: 0.3240349	total: 1.8s	remaining: 3.63s
# 174:	learn: 0.3235812	total: 1.81s	remaining: 3.62s
# 175:	learn: 0.3232478	total: 1.82s	remaining: 3.61s
# 176:	learn: 0.3227493	total: 1.83s	remaining: 3.6s
# 177:	learn: 0.3223331	total: 1.84s	remaining: 3.59s
# 178:	learn: 0.3217684	total: 1.85s	remaining: 3.58s
# 179:	learn: 0.3213096	total: 1.86s	remaining: 3.56s
# 180:	learn: 0.3212300	total: 1.86s	remaining: 3.54s
# 181:	learn: 0.3208517	total: 1.87s	remaining: 3.53s
# 182:	learn: 0.3202526	total: 1.88s	remaining: 3.51s
# 183:	learn: 0.3197293	total: 1.89s	remaining: 3.5s
# 184:	learn: 0.3192300	total: 1.9s	remaining: 3.49s
# 185:	learn: 0.3188505	total: 1.91s	remaining: 3.48s
# 186:	learn: 0.3183122	total: 1.92s	remaining: 3.47s
# 187:	learn: 0.3176618	total: 1.93s	remaining: 3.46s
# 188:	learn: 0.3169644	total: 1.94s	remaining: 3.45s
# 189:	learn: 0.3164678	total: 1.95s	remaining: 3.44s
# 190:	learn: 0.3159702	total: 1.96s	remaining: 3.43s
# 191:	learn: 0.3154269	total: 1.97s	remaining: 3.42s
# 192:	learn: 0.3150444	total: 1.98s	remaining: 3.4s
# 193:	learn: 0.3146869	total: 1.99s	remaining: 3.39s
# 194:	learn: 0.3140612	total: 2s	remaining: 3.38s
# 195:	learn: 0.3133930	total: 2s	remaining: 3.37s
# 196:	learn: 0.3128738	total: 2.01s	remaining: 3.35s
# 197:	learn: 0.3125095	total: 2.02s	remaining: 3.34s
# 198:	learn: 0.3121825	total: 2.03s	remaining: 3.33s
# 199:	learn: 0.3117766	total: 2.04s	remaining: 3.32s
# 200:	learn: 0.3112490	total: 2.05s	remaining: 3.31s
# 201:	learn: 0.3107942	total: 2.06s	remaining: 3.3s
# 202:	learn: 0.3102139	total: 2.07s	remaining: 3.29s
# 203:	learn: 0.3096964	total: 2.08s	remaining: 3.28s
# 204:	learn: 0.3091298	total: 2.09s	remaining: 3.27s
# 205:	learn: 0.3085591	total: 2.1s	remaining: 3.26s
# 206:	learn: 0.3078790	total: 2.11s	remaining: 3.25s
# 207:	learn: 0.3074859	total: 2.12s	remaining: 3.23s
# 208:	learn: 0.3069749	total: 2.13s	remaining: 3.22s
# 209:	learn: 0.3065315	total: 2.15s	remaining: 3.22s
# 210:	learn: 0.3061624	total: 2.16s	remaining: 3.21s
# 211:	learn: 0.3057592	total: 2.17s	remaining: 3.21s
# 212:	learn: 0.3050699	total: 2.19s	remaining: 3.21s
# 213:	learn: 0.3045203	total: 2.21s	remaining: 3.21s
# 214:	learn: 0.3037706	total: 2.22s	remaining: 3.21s
# 215:	learn: 0.3034343	total: 2.24s	remaining: 3.21s
# 216:	learn: 0.3027591	total: 2.25s	remaining: 3.2s
# 217:	learn: 0.3023290	total: 2.27s	remaining: 3.19s
# 218:	learn: 0.3020414	total: 2.28s	remaining: 3.19s
# 219:	learn: 0.3016451	total: 2.29s	remaining: 3.18s
# 220:	learn: 0.3011187	total: 2.31s	remaining: 3.18s
# 221:	learn: 0.3006909	total: 2.32s	remaining: 3.17s
# 222:	learn: 0.3002516	total: 2.33s	remaining: 3.15s
# 223:	learn: 0.2999692	total: 2.34s	remaining: 3.14s
# 224:	learn: 0.2996547	total: 2.35s	remaining: 3.13s
# 225:	learn: 0.2991973	total: 2.36s	remaining: 3.12s
# 226:	learn: 0.2986921	total: 2.37s	remaining: 3.11s
# 227:	learn: 0.2983663	total: 2.38s	remaining: 3.1s
# 228:	learn: 0.2978663	total: 2.39s	remaining: 3.09s
# 229:	learn: 0.2973568	total: 2.4s	remaining: 3.08s
# 230:	learn: 0.2970368	total: 2.41s	remaining: 3.06s
# 231:	learn: 0.2969329	total: 2.41s	remaining: 3.04s
# 232:	learn: 0.2965830	total: 2.42s	remaining: 3.03s
# 233:	learn: 0.2960855	total: 2.43s	remaining: 3.02s
# 234:	learn: 0.2957362	total: 2.44s	remaining: 3.01s
# 235:	learn: 0.2953520	total: 2.45s	remaining: 3s
# 236:	learn: 0.2949185	total: 2.46s	remaining: 2.99s
# 237:	learn: 0.2946173	total: 2.47s	remaining: 2.98s
# 238:	learn: 0.2941039	total: 2.48s	remaining: 2.97s
# 239:	learn: 0.2936110	total: 2.49s	remaining: 2.96s
# 240:	learn: 0.2932155	total: 2.5s	remaining: 2.94s
# 241:	learn: 0.2926051	total: 2.51s	remaining: 2.93s
# 242:	learn: 0.2923533	total: 2.52s	remaining: 2.92s
# 243:	learn: 0.2919506	total: 2.53s	remaining: 2.91s
# 244:	learn: 0.2917380	total: 2.54s	remaining: 2.9s
# 245:	learn: 0.2913174	total: 2.55s	remaining: 2.89s
# 246:	learn: 0.2909755	total: 2.56s	remaining: 2.88s
# 247:	learn: 0.2905470	total: 2.57s	remaining: 2.87s
# 248:	learn: 0.2902973	total: 2.58s	remaining: 2.86s
# 249:	learn: 0.2900416	total: 2.59s	remaining: 2.85s
# 250:	learn: 0.2896571	total: 2.6s	remaining: 2.84s
# 251:	learn: 0.2894102	total: 2.61s	remaining: 2.83s
# 252:	learn: 0.2890981	total: 2.62s	remaining: 2.81s
# 253:	learn: 0.2887107	total: 2.63s	remaining: 2.8s
# 254:	learn: 0.2883169	total: 2.64s	remaining: 2.79s
# 255:	learn: 0.2880695	total: 2.65s	remaining: 2.78s
# 256:	learn: 0.2876993	total: 2.66s	remaining: 2.77s
# 257:	learn: 0.2874419	total: 2.67s	remaining: 2.76s
# 258:	learn: 0.2869660	total: 2.68s	remaining: 2.75s
# 259:	learn: 0.2865536	total: 2.69s	remaining: 2.74s
# 260:	learn: 0.2860442	total: 2.7s	remaining: 2.73s
# 261:	learn: 0.2856213	total: 2.71s	remaining: 2.72s
# 262:	learn: 0.2852856	total: 2.72s	remaining: 2.71s
# 263:	learn: 0.2848920	total: 2.73s	remaining: 2.7s
# 264:	learn: 0.2845331	total: 2.74s	remaining: 2.69s
# 265:	learn: 0.2840543	total: 2.75s	remaining: 2.67s
# 266:	learn: 0.2836859	total: 2.76s	remaining: 2.66s
# 267:	learn: 0.2832602	total: 2.77s	remaining: 2.65s
# 268:	learn: 0.2829526	total: 2.78s	remaining: 2.64s
# 269:	learn: 0.2824127	total: 2.79s	remaining: 2.63s
# 270:	learn: 0.2819648	total: 2.8s	remaining: 2.62s
# 271:	learn: 0.2816711	total: 2.81s	remaining: 2.61s
# 272:	learn: 0.2812481	total: 2.82s	remaining: 2.6s
# 273:	learn: 0.2810614	total: 2.83s	remaining: 2.59s
# 274:	learn: 0.2805799	total: 2.84s	remaining: 2.58s
# 275:	learn: 0.2799643	total: 2.85s	remaining: 2.57s
# 276:	learn: 0.2796200	total: 2.86s	remaining: 2.56s
# 277:	learn: 0.2791948	total: 2.87s	remaining: 2.55s
# 278:	learn: 0.2788016	total: 2.88s	remaining: 2.54s
# 279:	learn: 0.2782875	total: 2.89s	remaining: 2.53s
# 280:	learn: 0.2780693	total: 2.9s	remaining: 2.52s
# 281:	learn: 0.2777371	total: 2.91s	remaining: 2.51s
# 282:	learn: 0.2774494	total: 2.92s	remaining: 2.5s
# 283:	learn: 0.2772306	total: 2.93s	remaining: 2.49s
# 284:	learn: 0.2767880	total: 2.95s	remaining: 2.48s
# 285:	learn: 0.2765600	total: 2.96s	remaining: 2.47s
# 286:	learn: 0.2762108	total: 2.97s	remaining: 2.46s
# 287:	learn: 0.2757802	total: 2.98s	remaining: 2.45s
# 288:	learn: 0.2754523	total: 2.99s	remaining: 2.44s
# 289:	learn: 0.2750996	total: 3s	remaining: 2.43s
# 290:	learn: 0.2746242	total: 3.01s	remaining: 2.42s
# 291:	learn: 0.2742473	total: 3.02s	remaining: 2.41s
# 292:	learn: 0.2739830	total: 3.03s	remaining: 2.4s
# 293:	learn: 0.2737180	total: 3.04s	remaining: 2.39s
# 294:	learn: 0.2733804	total: 3.05s	remaining: 2.38s
# 295:	learn: 0.2729241	total: 3.06s	remaining: 2.37s
# 296:	learn: 0.2724286	total: 3.07s	remaining: 2.36s
# 297:	learn: 0.2721565	total: 3.08s	remaining: 2.35s
# 298:	learn: 0.2717406	total: 3.09s	remaining: 2.34s
# 299:	learn: 0.2714226	total: 3.1s	remaining: 2.33s
# 300:	learn: 0.2708366	total: 3.11s	remaining: 2.31s
# 301:	learn: 0.2704854	total: 3.12s	remaining: 2.31s
# 302:	learn: 0.2701196	total: 3.13s	remaining: 2.29s
# 303:	learn: 0.2696966	total: 3.14s	remaining: 2.29s
# 304:	learn: 0.2694855	total: 3.15s	remaining: 2.28s
# 305:	learn: 0.2691282	total: 3.17s	remaining: 2.27s
# 306:	learn: 0.2689191	total: 3.18s	remaining: 2.26s
# 307:	learn: 0.2687137	total: 3.19s	remaining: 2.25s
# 308:	learn: 0.2683247	total: 3.2s	remaining: 2.24s
# 309:	learn: 0.2679198	total: 3.21s	remaining: 2.23s
# 310:	learn: 0.2675687	total: 3.22s	remaining: 2.22s
# 311:	learn: 0.2671520	total: 3.23s	remaining: 2.21s
# 312:	learn: 0.2669044	total: 3.24s	remaining: 2.2s
# 313:	learn: 0.2666156	total: 3.25s	remaining: 2.19s
# 314:	learn: 0.2663239	total: 3.27s	remaining: 2.18s
# 315:	learn: 0.2660519	total: 3.28s	remaining: 2.17s
# 316:	learn: 0.2657602	total: 3.29s	remaining: 2.16s
# 317:	learn: 0.2654632	total: 3.3s	remaining: 2.15s
# 318:	learn: 0.2650055	total: 3.31s	remaining: 2.14s
# 319:	learn: 0.2646543	total: 3.32s	remaining: 2.13s
# 320:	learn: 0.2643257	total: 3.33s	remaining: 2.12s
# 321:	learn: 0.2639057	total: 3.34s	remaining: 2.11s
# 322:	learn: 0.2634773	total: 3.35s	remaining: 2.1s
# 323:	learn: 0.2630178	total: 3.36s	remaining: 2.09s
# 324:	learn: 0.2626629	total: 3.37s	remaining: 2.08s
# 325:	learn: 0.2624275	total: 3.38s	remaining: 2.07s
# 326:	learn: 0.2619338	total: 3.39s	remaining: 2.06s
# 327:	learn: 0.2614058	total: 3.4s	remaining: 2.04s
# 328:	learn: 0.2610320	total: 3.42s	remaining: 2.03s
# 329:	learn: 0.2606213	total: 3.42s	remaining: 2.02s
# 330:	learn: 0.2602716	total: 3.44s	remaining: 2.01s
# 331:	learn: 0.2597409	total: 3.45s	remaining: 2s
# 332:	learn: 0.2594112	total: 3.46s	remaining: 1.99s
# 333:	learn: 0.2590657	total: 3.47s	remaining: 1.98s
# 334:	learn: 0.2587009	total: 3.48s	remaining: 1.97s
# 335:	learn: 0.2584063	total: 3.49s	remaining: 1.96s
# 336:	learn: 0.2579325	total: 3.5s	remaining: 1.95s
# 337:	learn: 0.2576337	total: 3.51s	remaining: 1.94s
# 338:	learn: 0.2572841	total: 3.52s	remaining: 1.93s
# 339:	learn: 0.2571972	total: 3.52s	remaining: 1.92s
# 340:	learn: 0.2568937	total: 3.53s	remaining: 1.91s
# 341:	learn: 0.2565617	total: 3.54s	remaining: 1.9s
# 342:	learn: 0.2561806	total: 3.55s	remaining: 1.89s
# 343:	learn: 0.2558071	total: 3.56s	remaining: 1.88s
# 344:	learn: 0.2554825	total: 3.57s	remaining: 1.86s
# 345:	learn: 0.2552920	total: 3.58s	remaining: 1.85s
# 346:	learn: 0.2548650	total: 3.59s	remaining: 1.84s
# 347:	learn: 0.2544118	total: 3.6s	remaining: 1.83s
# 348:	learn: 0.2541344	total: 3.62s	remaining: 1.82s
# 349:	learn: 0.2538237	total: 3.62s	remaining: 1.81s
# 350:	learn: 0.2535530	total: 3.63s	remaining: 1.8s
# 351:	learn: 0.2532445	total: 3.64s	remaining: 1.79s
# 352:	learn: 0.2529879	total: 3.65s	remaining: 1.78s
# 353:	learn: 0.2528011	total: 3.67s	remaining: 1.77s
# 354:	learn: 0.2525701	total: 3.67s	remaining: 1.76s
# 355:	learn: 0.2522496	total: 3.69s	remaining: 1.75s
# 356:	learn: 0.2519942	total: 3.7s	remaining: 1.74s
# 357:	learn: 0.2516272	total: 3.71s	remaining: 1.73s
# 358:	learn: 0.2512608	total: 3.72s	remaining: 1.72s
# 359:	learn: 0.2509913	total: 3.73s	remaining: 1.71s
# 360:	learn: 0.2508172	total: 3.73s	remaining: 1.7s
# 361:	learn: 0.2505184	total: 3.75s	remaining: 1.69s
# 362:	learn: 0.2500755	total: 3.75s	remaining: 1.68s
# 363:	learn: 0.2498701	total: 3.77s	remaining: 1.67s
# 364:	learn: 0.2495395	total: 3.78s	remaining: 1.66s
# 365:	learn: 0.2492949	total: 3.79s	remaining: 1.65s
# 366:	learn: 0.2489967	total: 3.8s	remaining: 1.63s
# 367:	learn: 0.2486732	total: 3.81s	remaining: 1.62s
# 368:	learn: 0.2484495	total: 3.82s	remaining: 1.61s
# 369:	learn: 0.2481978	total: 3.83s	remaining: 1.6s
# 370:	learn: 0.2480437	total: 3.84s	remaining: 1.59s
# 371:	learn: 0.2475586	total: 3.85s	remaining: 1.58s
# 372:	learn: 0.2472393	total: 3.86s	remaining: 1.57s
# 373:	learn: 0.2469078	total: 3.87s	remaining: 1.56s
# 374:	learn: 0.2465516	total: 3.88s	remaining: 1.55s
# 375:	learn: 0.2462330	total: 3.89s	remaining: 1.54s
# 376:	learn: 0.2458607	total: 3.9s	remaining: 1.53s
# 377:	learn: 0.2456265	total: 3.91s	remaining: 1.52s
# 378:	learn: 0.2454507	total: 3.92s	remaining: 1.51s
# 379:	learn: 0.2451417	total: 3.93s	remaining: 1.5s
# 380:	learn: 0.2446938	total: 3.94s	remaining: 1.49s
# 381:	learn: 0.2443040	total: 3.95s	remaining: 1.48s
# 382:	learn: 0.2440223	total: 3.96s	remaining: 1.47s
# 383:	learn: 0.2435760	total: 3.97s	remaining: 1.46s
# 384:	learn: 0.2432971	total: 3.98s	remaining: 1.45s
# 385:	learn: 0.2429596	total: 3.99s	remaining: 1.44s
# 386:	learn: 0.2424939	total: 4s	remaining: 1.43s
# 387:	learn: 0.2421267	total: 4.01s	remaining: 1.42s
# 388:	learn: 0.2418471	total: 4.02s	remaining: 1.4s
# 389:	learn: 0.2415020	total: 4.03s	remaining: 1.39s
# 390:	learn: 0.2412726	total: 4.04s	remaining: 1.38s
# 391:	learn: 0.2410355	total: 4.05s	remaining: 1.37s
# 392:	learn: 0.2406397	total: 4.06s	remaining: 1.36s
# 393:	learn: 0.2403706	total: 4.07s	remaining: 1.35s
# 394:	learn: 0.2399443	total: 4.08s	remaining: 1.34s
# 395:	learn: 0.2396619	total: 4.09s	remaining: 1.33s
# 396:	learn: 0.2392475	total: 4.1s	remaining: 1.32s
# 397:	learn: 0.2389571	total: 4.11s	remaining: 1.31s
# 398:	learn: 0.2388485	total: 4.13s	remaining: 1.3s
# 399:	learn: 0.2386211	total: 4.14s	remaining: 1.29s
# 400:	learn: 0.2383363	total: 4.16s	remaining: 1.28s
# 401:	learn: 0.2380096	total: 4.17s	remaining: 1.28s
# 402:	learn: 0.2376993	total: 4.18s	remaining: 1.27s
# 403:	learn: 0.2375095	total: 4.2s	remaining: 1.26s
# ...
# 217:	learn: 0.3697227	total: 2.52s	remaining: 3.55s
# 218:	learn: 0.3695644	total: 2.53s	remaining: 3.53s
# 219:	learn: 0.3693721	total: 2.54s	remaining: 3.52s
# 220:	learn: 0.3691513	total: 2.55s	remaining: 3.51s
# 221:	learn: 0.3688302	total: 2.56s	remaining: 3.5s
# 222:	learn: 0.3687508	total: 2.57s	remaining: 3.48s
# 223:	learn: 0.3685232	total: 2.58s	remaining: 3.47s
# 224:	learn: 0.3682181	total: 2.59s	remaining: 3.46s
# 225:	learn: 0.3680550	total: 2.61s	remaining: 3.45s
# 226:	learn: 0.3677996	total: 2.62s	remaining: 3.44s
# 227:	learn: 0.3674461	total: 2.64s	remaining: 3.44s
# 228:	learn: 0.3671886	total: 2.65s	remaining: 3.43s
# 229:	learn: 0.3669891	total: 2.67s	remaining: 3.42s
# 230:	learn: 0.3666524	total: 2.68s	remaining: 3.41s
# 231:	learn: 0.3664222	total: 2.69s	remaining: 3.4s
# 232:	learn: 0.3664048	total: 2.69s	remaining: 3.37s
# 233:	learn: 0.3661363	total: 2.7s	remaining: 3.36s
# 234:	learn: 0.3658657	total: 2.71s	remaining: 3.35s
# 235:	learn: 0.3656691	total: 2.73s	remaining: 3.34s
# 236:	learn: 0.3654572	total: 2.74s	remaining: 3.33s
# 237:	learn: 0.3651684	total: 2.75s	remaining: 3.31s
# 238:	learn: 0.3649613	total: 2.76s	remaining: 3.3s
# 239:	learn: 0.3648036	total: 2.77s	remaining: 3.29s
# 240:	learn: 0.3645897	total: 2.78s	remaining: 3.28s
# 241:	learn: 0.3643461	total: 2.79s	remaining: 3.26s
# 242:	learn: 0.3642197	total: 2.8s	remaining: 3.25s
# 243:	learn: 0.3639256	total: 2.81s	remaining: 3.24s
# 244:	learn: 0.3636533	total: 2.82s	remaining: 3.23s
# 245:	learn: 0.3634560	total: 2.83s	remaining: 3.21s
# 246:	learn: 0.3632656	total: 2.85s	remaining: 3.2s
# 247:	learn: 0.3630271	total: 2.86s	remaining: 3.19s
# 248:	learn: 0.3628030	total: 2.87s	remaining: 3.18s
# 249:	learn: 0.3626160	total: 2.88s	remaining: 3.17s
# 250:	learn: 0.3624068	total: 2.89s	remaining: 3.16s
# 251:	learn: 0.3621361	total: 2.9s	remaining: 3.15s
# 252:	learn: 0.3618888	total: 2.92s	remaining: 3.13s
# 253:	learn: 0.3617401	total: 2.93s	remaining: 3.12s
# 254:	learn: 0.3615829	total: 2.94s	remaining: 3.11s
# 255:	learn: 0.3613463	total: 2.95s	remaining: 3.1s
# 256:	learn: 0.3611150	total: 2.96s	remaining: 3.08s
# 257:	learn: 0.3608965	total: 2.97s	remaining: 3.07s
# 258:	learn: 0.3606953	total: 2.98s	remaining: 3.06s
# 259:	learn: 0.3605656	total: 2.99s	remaining: 3.05s
# 260:	learn: 0.3603251	total: 3s	remaining: 3.04s
# 261:	learn: 0.3600598	total: 3.02s	remaining: 3.03s
# 262:	learn: 0.3598670	total: 3.02s	remaining: 3.01s
# 263:	learn: 0.3595681	total: 3.04s	remaining: 3s
# 264:	learn: 0.3593468	total: 3.05s	remaining: 2.99s
# 265:	learn: 0.3590165	total: 3.06s	remaining: 2.98s
# 266:	learn: 0.3588255	total: 3.07s	remaining: 2.97s
# 267:	learn: 0.3585385	total: 3.08s	remaining: 2.96s
# 268:	learn: 0.3583605	total: 3.09s	remaining: 2.94s
# 269:	learn: 0.3582577	total: 3.1s	remaining: 2.93s
# 270:	learn: 0.3580574	total: 3.12s	remaining: 2.92s
# 271:	learn: 0.3578746	total: 3.13s	remaining: 2.91s
# 272:	learn: 0.3575901	total: 3.14s	remaining: 2.9s
# 273:	learn: 0.3573949	total: 3.15s	remaining: 2.88s
# 274:	learn: 0.3571418	total: 3.16s	remaining: 2.87s
# 275:	learn: 0.3569984	total: 3.17s	remaining: 2.86s
# 276:	learn: 0.3568250	total: 3.18s	remaining: 2.85s
# 277:	learn: 0.3566611	total: 3.19s	remaining: 2.84s
# 278:	learn: 0.3565278	total: 3.2s	remaining: 2.82s
# 279:	learn: 0.3562630	total: 3.21s	remaining: 2.81s
# 280:	learn: 0.3560908	total: 3.22s	remaining: 2.8s
# 281:	learn: 0.3558645	total: 3.23s	remaining: 2.79s
# 282:	learn: 0.3557404	total: 3.25s	remaining: 2.78s
# 283:	learn: 0.3554625	total: 3.26s	remaining: 2.76s
# 284:	learn: 0.3553229	total: 3.27s	remaining: 2.75s
# 285:	learn: 0.3550706	total: 3.28s	remaining: 2.74s
# 286:	learn: 0.3548951	total: 3.29s	remaining: 2.73s
# 287:	learn: 0.3547302	total: 3.3s	remaining: 2.72s
# 288:	learn: 0.3546153	total: 3.31s	remaining: 2.71s
# 289:	learn: 0.3544875	total: 3.32s	remaining: 2.69s
# 290:	learn: 0.3543076	total: 3.34s	remaining: 2.68s
# 291:	learn: 0.3541603	total: 3.35s	remaining: 2.67s
# 292:	learn: 0.3539832	total: 3.36s	remaining: 2.66s
# 293:	learn: 0.3537976	total: 3.37s	remaining: 2.65s
# 294:	learn: 0.3534769	total: 3.38s	remaining: 2.63s
# 295:	learn: 0.3533457	total: 3.39s	remaining: 2.62s
# 296:	learn: 0.3533386	total: 3.39s	remaining: 2.6s
# 297:	learn: 0.3531026	total: 3.4s	remaining: 2.59s
# 298:	learn: 0.3528291	total: 3.41s	remaining: 2.58s
# 299:	learn: 0.3525324	total: 3.42s	remaining: 2.57s
# 300:	learn: 0.3523352	total: 3.44s	remaining: 2.56s
# 301:	learn: 0.3521227	total: 3.45s	remaining: 2.54s
# 302:	learn: 0.3519783	total: 3.46s	remaining: 2.53s
# 303:	learn: 0.3517652	total: 3.47s	remaining: 2.52s
# 304:	learn: 0.3515990	total: 3.48s	remaining: 2.51s
# 305:	learn: 0.3514530	total: 3.5s	remaining: 2.5s
# 306:	learn: 0.3512571	total: 3.51s	remaining: 2.49s
# 307:	learn: 0.3510370	total: 3.52s	remaining: 2.48s
# 308:	learn: 0.3508392	total: 3.53s	remaining: 2.47s
# 309:	learn: 0.3505713	total: 3.54s	remaining: 2.46s
# 310:	learn: 0.3504298	total: 3.56s	remaining: 2.45s
# 311:	learn: 0.3502804	total: 3.57s	remaining: 2.44s
# 312:	learn: 0.3501631	total: 3.58s	remaining: 2.43s
# 313:	learn: 0.3499315	total: 3.6s	remaining: 2.42s
# 314:	learn: 0.3497244	total: 3.61s	remaining: 2.41s
# 315:	learn: 0.3495326	total: 3.63s	remaining: 2.4s
# 316:	learn: 0.3493330	total: 3.64s	remaining: 2.39s
# 317:	learn: 0.3490835	total: 3.66s	remaining: 2.38s
# 318:	learn: 0.3488875	total: 3.67s	remaining: 2.37s
# 319:	learn: 0.3486854	total: 3.68s	remaining: 2.36s
# 320:	learn: 0.3485076	total: 3.69s	remaining: 2.35s
# 321:	learn: 0.3482913	total: 3.7s	remaining: 2.33s
# 322:	learn: 0.3482038	total: 3.71s	remaining: 2.32s
# 323:	learn: 0.3480589	total: 3.73s	remaining: 2.31s
# 324:	learn: 0.3478412	total: 3.74s	remaining: 2.3s
# 325:	learn: 0.3475524	total: 3.75s	remaining: 2.29s
# 326:	learn: 0.3474336	total: 3.76s	remaining: 2.27s
# 327:	learn: 0.3472695	total: 3.77s	remaining: 2.26s
# 328:	learn: 0.3471468	total: 3.78s	remaining: 2.25s
# 329:	learn: 0.3470641	total: 3.79s	remaining: 2.24s
# 330:	learn: 0.3468847	total: 3.8s	remaining: 2.23s
# 331:	learn: 0.3466130	total: 3.81s	remaining: 2.21s
# 332:	learn: 0.3462806	total: 3.82s	remaining: 2.2s
# 333:	learn: 0.3461363	total: 3.83s	remaining: 2.19s
# 334:	learn: 0.3458899	total: 3.84s	remaining: 2.18s
# 335:	learn: 0.3457365	total: 3.85s	remaining: 2.17s
# 336:	learn: 0.3454776	total: 3.87s	remaining: 2.16s
# 337:	learn: 0.3451788	total: 3.88s	remaining: 2.14s
# 338:	learn: 0.3450538	total: 3.89s	remaining: 2.13s
# 339:	learn: 0.3448407	total: 3.9s	remaining: 2.12s
# 340:	learn: 0.3446898	total: 3.91s	remaining: 2.11s
# 341:	learn: 0.3444184	total: 3.92s	remaining: 2.1s
# 342:	learn: 0.3443127	total: 3.93s	remaining: 2.08s
# 343:	learn: 0.3442026	total: 3.94s	remaining: 2.07s
# 344:	learn: 0.3439828	total: 3.95s	remaining: 2.06s
# 345:	learn: 0.3437972	total: 3.96s	remaining: 2.05s
# 346:	learn: 0.3436655	total: 3.98s	remaining: 2.04s
# 347:	learn: 0.3434439	total: 3.99s	remaining: 2.03s
# 348:	learn: 0.3432634	total: 4s	remaining: 2.02s
# 349:	learn: 0.3430675	total: 4.01s	remaining: 2s
# 350:	learn: 0.3429192	total: 4.02s	remaining: 1.99s
# 351:	learn: 0.3427339	total: 4.03s	remaining: 1.98s
# 352:	learn: 0.3426070	total: 4.04s	remaining: 1.97s
# 353:	learn: 0.3424375	total: 4.05s	remaining: 1.96s
# 354:	learn: 0.3423208	total: 4.07s	remaining: 1.95s
# 355:	learn: 0.3420762	total: 4.08s	remaining: 1.94s
# 356:	learn: 0.3418533	total: 4.09s	remaining: 1.92s
# 357:	learn: 0.3416465	total: 4.1s	remaining: 1.91s
# 358:	learn: 0.3415377	total: 4.11s	remaining: 1.9s
# 359:	learn: 0.3413079	total: 4.12s	remaining: 1.89s
# 360:	learn: 0.3412413	total: 4.13s	remaining: 1.88s
# 361:	learn: 0.3410017	total: 4.14s	remaining: 1.86s
# 362:	learn: 0.3407644	total: 4.15s	remaining: 1.85s
# 363:	learn: 0.3405543	total: 4.17s	remaining: 1.84s
# 364:	learn: 0.3403982	total: 4.18s	remaining: 1.83s
# 365:	learn: 0.3402522	total: 4.19s	remaining: 1.82s
# 366:	learn: 0.3401416	total: 4.2s	remaining: 1.81s
# 367:	learn: 0.3400661	total: 4.21s	remaining: 1.8s
# 368:	learn: 0.3398924	total: 4.22s	remaining: 1.78s
# 369:	learn: 0.3397728	total: 4.23s	remaining: 1.77s
# 370:	learn: 0.3396323	total: 4.25s	remaining: 1.76s
# 371:	learn: 0.3395441	total: 4.26s	remaining: 1.75s
# 372:	learn: 0.3393859	total: 4.27s	remaining: 1.74s
# 373:	learn: 0.3392371	total: 4.28s	remaining: 1.73s
# 374:	learn: 0.3390738	total: 4.29s	remaining: 1.72s
# 375:	learn: 0.3388585	total: 4.3s	remaining: 1.7s
# 376:	learn: 0.3387040	total: 4.31s	remaining: 1.69s
# 377:	learn: 0.3385883	total: 4.32s	remaining: 1.68s
# 378:	learn: 0.3384678	total: 4.33s	remaining: 1.67s
# 379:	learn: 0.3383223	total: 4.35s	remaining: 1.66s
# 380:	learn: 0.3381479	total: 4.36s	remaining: 1.65s
# 381:	learn: 0.3379657	total: 4.37s	remaining: 1.64s
# 382:	learn: 0.3378502	total: 4.38s	remaining: 1.62s
# 383:	learn: 0.3377015	total: 4.39s	remaining: 1.61s
# 384:	learn: 0.3375284	total: 4.4s	remaining: 1.6s
# 385:	learn: 0.3374185	total: 4.41s	remaining: 1.59s
# 386:	learn: 0.3372188	total: 4.42s	remaining: 1.58s
# 387:	learn: 0.3370740	total: 4.43s	remaining: 1.57s
# 388:	learn: 0.3369900	total: 4.45s	remaining: 1.55s
# 389:	learn: 0.3367963	total: 4.46s	remaining: 1.54s
# 390:	learn: 0.3365207	total: 4.47s	remaining: 1.53s
# 391:	learn: 0.3363186	total: 4.48s	remaining: 1.52s
# 392:	learn: 0.3361364	total: 4.49s	remaining: 1.51s
# 393:	learn: 0.3358714	total: 4.5s	remaining: 1.5s
# 394:	learn: 0.3357294	total: 4.51s	remaining: 1.49s
# 395:	learn: 0.3356275	total: 4.53s	remaining: 1.48s
# 396:	learn: 0.3355120	total: 4.54s	remaining: 1.46s
# 397:	learn: 0.3353761	total: 4.55s	remaining: 1.45s
# 398:	learn: 0.3351824	total: 4.56s	remaining: 1.44s
# 399:	learn: 0.3349607	total: 4.58s	remaining: 1.43s
# 400:	learn: 0.3348238	total: 4.59s	remaining: 1.42s
# 401:	learn: 0.3347239	total: 4.61s	remaining: 1.41s
# 402:	learn: 0.3345556	total: 4.62s	remaining: 1.4s
# 403:	learn: 0.3343605	total: 4.64s	remaining: 1.39s
# 404:	learn: 0.3341454	total: 4.65s	remaining: 1.38s
# 405:	learn: 0.3340568	total: 4.66s	remaining: 1.37s
# 406:	learn: 0.3339101	total: 4.67s	remaining: 1.35s
# 407:	learn: 0.3337649	total: 4.68s	remaining: 1.34s
# 408:	learn: 0.3335598	total: 4.7s	remaining: 1.33s
# 409:	learn: 0.3334472	total: 4.71s	remaining: 1.32s
# 410:	learn: 0.3333084	total: 4.72s	remaining: 1.31s
# 411:	learn: 0.3332155	total: 4.73s	remaining: 1.3s
# 412:	learn: 0.3330918	total: 4.74s	remaining: 1.28s
# 413:	learn: 0.3329988	total: 4.75s	remaining: 1.27s
# 414:	learn: 0.3329146	total: 4.76s	remaining: 1.26s
# 415:	learn: 0.3327817	total: 4.77s	remaining: 1.25s
# 416:	learn: 0.3326851	total: 4.78s	remaining: 1.24s
# 417:	learn: 0.3326080	total: 4.79s	remaining: 1.23s
# 418:	learn: 0.3324175	total: 4.8s	remaining: 1.22s
# 419:	learn: 0.3323258	total: 4.82s	remaining: 1.2s
# 420:	learn: 0.3321767	total: 4.83s	remaining: 1.19s
# 421:	learn: 0.3320072	total: 4.84s	remaining: 1.18s
# 422:	learn: 0.3318355	total: 4.85s	remaining: 1.17s
# 423:	learn: 0.3316299	total: 4.86s	remaining: 1.16s
# 424:	learn: 0.3315432	total: 4.87s	remaining: 1.15s
# 425:	learn: 0.3313406	total: 4.88s	remaining: 1.13s
# 426:	learn: 0.3311519	total: 4.89s	remaining: 1.12s
# 427:	learn: 0.3310599	total: 4.9s	remaining: 1.11s
# 428:	learn: 0.3309386	total: 4.91s	remaining: 1.1s
# 429:	learn: 0.3307172	total: 4.92s	remaining: 1.09s
# 430:	learn: 0.3305956	total: 4.93s	remaining: 1.08s
# 431:	learn: 0.3305225	total: 4.95s	remaining: 1.06s
# 432:	learn: 0.3303563	total: 4.96s	remaining: 1.05s
# 433:	learn: 0.3302393	total: 4.97s	remaining: 1.04s
# 434:	learn: 0.3300911	total: 4.98s	remaining: 1.03s
# 435:	learn: 0.3299546	total: 4.99s	remaining: 1.02s
# 436:	learn: 0.3296853	total: 5s	remaining: 1.01s
# 437:	learn: 0.3295841	total: 5.01s	remaining: 996ms
# 438:	learn: 0.3293723	total: 5.03s	remaining: 984ms
# 439:	learn: 0.3291949	total: 5.04s	remaining: 973ms
# 440:	learn: 0.3290443	total: 5.05s	remaining: 962ms
# 441:	learn: 0.3289120	total: 5.06s	remaining: 950ms
# 442:	learn: 0.3287603	total: 5.07s	remaining: 939ms
# 443:	learn: 0.3286060	total: 5.08s	remaining: 927ms
# 444:	learn: 0.3285420	total: 5.09s	remaining: 916ms
# 445:	learn: 0.3284622	total: 5.1s	remaining: 904ms
# 446:	learn: 0.3283182	total: 5.12s	remaining: 893ms
# 447:	learn: 0.3281739	total: 5.13s	remaining: 882ms
# 448:	learn: 0.3279790	total: 5.14s	remaining: 870ms
# 449:	learn: 0.3278089	total: 5.15s	remaining: 859ms
# 450:	learn: 0.3276109	total: 5.16s	remaining: 847ms
# 451:	learn: 0.3275078	total: 5.17s	remaining: 836ms
# 452:	learn: 0.3273228	total: 5.19s	remaining: 824ms
# 453:	learn: 0.3271078	total: 5.2s	remaining: 814ms
# 454:	learn: 0.3269320	total: 5.21s	remaining: 802ms
# 455:	learn: 0.3267516	total: 5.23s	remaining: 791ms
# 456:	learn: 0.3266102	total: 5.24s	remaining: 780ms
# 457:	learn: 0.3264083	total: 5.25s	remaining: 768ms
# 458:	learn: 0.3261007	total: 5.26s	remaining: 757ms
# 459:	learn: 0.3259642	total: 5.28s	remaining: 745ms
# 460:	learn: 0.3257206	total: 5.29s	remaining: 735ms
# 461:	learn: 0.3255319	total: 5.3s	remaining: 723ms
# 462:	learn: 0.3254137	total: 5.32s	remaining: 712ms
# 463:	learn: 0.3252313	total: 5.34s	remaining: 702ms
# 464:	learn: 0.3250773	total: 5.35s	remaining: 690ms
# 465:	learn: 0.3248882	total: 5.37s	remaining: 679ms
# 466:	learn: 0.3247594	total: 5.38s	remaining: 668ms
# 467:	learn: 0.3245731	total: 5.4s	remaining: 657ms
# 468:	learn: 0.3243949	total: 5.41s	remaining: 646ms
# 469:	learn: 0.3242541	total: 5.42s	remaining: 635ms
# 470:	learn: 0.3241671	total: 5.44s	remaining: 623ms
# 471:	learn: 0.3239996	total: 5.45s	remaining: 612ms
# 472:	learn: 0.3238604	total: 5.46s	remaining: 601ms
# 473:	learn: 0.3236844	total: 5.48s	remaining: 590ms
# 474:	learn: 0.3235820	total: 5.49s	remaining: 578ms
# 475:	learn: 0.3234245	total: 5.51s	remaining: 567ms
# 476:	learn: 0.3233187	total: 5.52s	remaining: 556ms
# 477:	learn: 0.3231973	total: 5.53s	remaining: 544ms
# 478:	learn: 0.3230726	total: 5.55s	remaining: 533ms
# 479:	learn: 0.3228300	total: 5.56s	remaining: 521ms
# 480:	learn: 0.3227693	total: 5.57s	remaining: 510ms
# 481:	learn: 0.3226733	total: 5.59s	remaining: 498ms
# 482:	learn: 0.3225565	total: 5.6s	remaining: 487ms
# 483:	learn: 0.3223236	total: 5.61s	remaining: 475ms
# 484:	learn: 0.3222533	total: 5.62s	remaining: 464ms
# 485:	learn: 0.3220081	total: 5.63s	remaining: 452ms
# 486:	learn: 0.3217635	total: 5.65s	remaining: 441ms
# 487:	learn: 0.3216592	total: 5.66s	remaining: 429ms
# 488:	learn: 0.3215671	total: 5.67s	remaining: 418ms
# 489:	learn: 0.3214425	total: 5.69s	remaining: 406ms
# 490:	learn: 0.3213693	total: 5.7s	remaining: 395ms
# 491:	learn: 0.3211824	total: 5.72s	remaining: 383ms
# 492:	learn: 0.3210376	total: 5.73s	remaining: 372ms
# 493:	learn: 0.3208680	total: 5.74s	remaining: 360ms
# 494:	learn: 0.3206952	total: 5.75s	remaining: 349ms
# 495:	learn: 0.3205153	total: 5.76s	remaining: 337ms
# 496:	learn: 0.3202797	total: 5.77s	remaining: 325ms
# 497:	learn: 0.3201451	total: 5.78s	remaining: 314ms
# 498:	learn: 0.3200330	total: 5.79s	remaining: 302ms
# 499:	learn: 0.3199026	total: 5.81s	remaining: 290ms
# 500:	learn: 0.3197889	total: 5.82s	remaining: 279ms
# 501:	learn: 0.3197337	total: 5.83s	remaining: 267ms
# 502:	learn: 0.3196590	total: 5.84s	remaining: 255ms
# 503:	learn: 0.3195536	total: 5.86s	remaining: 244ms
# 504:	learn: 0.3193777	total: 5.87s	remaining: 232ms
# 505:	learn: 0.3192565	total: 5.88s	remaining: 221ms
# 506:	learn: 0.3192027	total: 5.89s	remaining: 209ms
# 507:	learn: 0.3191028	total: 5.9s	remaining: 197ms
# 508:	learn: 0.3189340	total: 5.91s	remaining: 186ms
# 509:	learn: 0.3187899	total: 5.92s	remaining: 174ms
# 510:	learn: 0.3185511	total: 5.93s	remaining: 163ms
# 511:	learn: 0.3184126	total: 5.95s	remaining: 151ms
# 512:	learn: 0.3183439	total: 5.96s	remaining: 139ms
# 513:	learn: 0.3181745	total: 5.97s	remaining: 128ms
# 514:	learn: 0.3180439	total: 5.98s	remaining: 116ms
# 515:	learn: 0.3178712	total: 5.99s	remaining: 105ms
# 516:	learn: 0.3176836	total: 6s	remaining: 92.9ms
# 517:	learn: 0.3176129	total: 6.02s	remaining: 81.3ms
# 518:	learn: 0.3175059	total: 6.03s	remaining: 69.7ms
# 519:	learn: 0.3174026	total: 6.04s	remaining: 58.1ms
# 520:	learn: 0.3172933	total: 6.05s	remaining: 46.5ms
# 521:	learn: 0.3170853	total: 6.06s	remaining: 34.8ms
# 522:	learn: 0.3169595	total: 6.07s	remaining: 23.2ms
# 523:	learn: 0.3168430	total: 6.08s	remaining: 11.6ms
# 524:	learn: 0.3166725	total: 6.09s	remaining: 0us
# 	 -> Scored 0.155
#
#  Local CV is 0.184

# %%
#1から0でクリップしたほうがいいかもしれない

pred_test = np.mean(pred_tests, 0)
df_test['pred'] = pred_test

final_sub = df_test[['ID', 'pred']].copy()
final_sub.to_csv('submissionStage1.csv', index=False)

display(final_sub)

pred_test_s2 = np.mean(pred_tests_s2, 0)
df_test_s2['pred'] = pred_test_s2

final_sub_s2 = df_test_s2[['ID', 'pred']].copy()
final_sub_s2.to_csv('submissionStage2.csv', index=False)

display(final_sub_s2)
# Out:
#                     ID      pred
# 0       2021_1101_1102  0.319430
# 1       2021_1101_1103  0.253045
# 2       2021_1101_1104  0.282571
# 3       2021_1101_1105  0.320934
# 4       2021_1101_1106  0.319781
# ...                ...       ...
# 507103  2024_3475_3477  0.595369
# 507104  2024_3475_3478  0.588731
# 507105  2024_3476_3477  0.470971
# 507106  2024_3476_3478  0.463063
# 507107  2024_3477_3478  0.476011
#
# [507108 rows x 2 columns]
#                     ID      pred
# 0       2025_1101_1102  0.505870
# 1       2025_1101_1103  0.410217
# 2       2025_1101_1104  0.318974
# 3       2025_1101_1105  0.524680
# 4       2025_1101_1106  0.495735
# ...                ...       ...
# 131402  2025_3477_3479  0.479208
# 131403  2025_3477_3480  0.498398
# 131404  2025_3478_3479  0.457897
# 131405  2025_3478_3480  0.472242
# 131406  2025_3479_3480  0.498059
#
# [131407 rows x 2 columns]
